# %% [markdown]
# # **Proyecto 1: electroencefalograma (EEG)**
#
#
# **Integrantes:**
#
# * Sara Mejía Zapata
# * María Camila Tobón Úsuga
#
# **Asignatura:** Bioseñales y Sistemas
#
# ---

# %% [markdown]
# ### **Descripción proyecto**
#
# El presente proyecto tiene como propósito analizar señales electroencefalográficas (EEG) asociadas al movimiento real e imaginación de movimiento de las manos y pies, con el fin de evaluar la factibilidad de desarrollar sistemas de interfaz cerebro computadora (BCI) no invasivos. Para ello, se emplea una base de datos que incluye registros de sujetos en diferentes condiciones experimentales, como movimiento de la mano derecha e izquierda, imaginación del movimiento y estado de reposo.
#
# En el desarrollo del proyecto se propone utilizar herramientas de programación en Python para el procesamiento y análisis de las señales, incluyendo la extracción de características relevantes como la densidad espectral de potencia en distintas bandas del EEG. Asimismo, se plantea comparar las diferentes condiciones mediante técnicas de análisis estadístico, con el objetivo de identificar patrones de actividad cerebral asociados a cada tarea.
#
# De esta manera, el proyecto busca comprender las diferencias en la actividad cerebral durante tareas motoras reales e imaginadas, y aportar al diseño de sistemas BCI capaces de interpretar la intención del usuario a partir de señales neuronales.

# %% [markdown]
# #### **CONSULTA**

# %% [markdown]
# *Consultar historia, uso y proyectos futuros relacionados con Interfaz Cerebro Computador*

# %% [markdown]
# **Historia**

# %% [markdown]
# Las interfaces cerebro–máquina (BCI, Brain-Computer Interface) nacen de la idea de poder controlar dispositivos mediante el pensamiento, algo que primero apareció en la ciencia ficción y luego en la ciencia real.Sus origenes comienzan en el siglo XX, el neurólogo alemán Hans Berger registra por primera vez la actividad eléctrica del cerebro desde allí nace el EEG(electroencefalograma).En ese trabajo, Berger ya identificaba dos tipos de ondas cerebrales: las ondas alfa y beta. Las ondas alfa, con rango de frecuencias entre 8 – 12 Hertz, son más prominentes cuando un sujeto está en estado de relajación con los ojos cerrados y desaparecen cuando se abren los ojos. Las ondas beta, con rango de frecuencias entre 15 – 25 Hertz, están asociadas con un estado de alerta y concentración.
#
# En las décadas de 1950 y 1960, Joe Kamiya y sus colegas de la Universidad de Chicago descubrieron que una persona podía aprender a controlar voluntariamente la intensidad de sus ondas cerebrales, dando origen a la disciplina conocida como neurofeedback.Para 1973 , el término Interfaz Cerebro-Computadora (Brain-Computer Interface – BCI en inglés) fue introducido por primera vez por Jacques J. Vidal, un investigador belga trabajando en la Universidad de California. En el artículo (Vidal, 1973), el autor propuso la idea de utilizar las señales eléctricas del cerebro para permitir a una persona controlar computadoras o prótesis. Sin embargo, no fue hasta los años 1980s que investigadores en Estados Unidos y Europa lograron llevar a la práctica estas ideas.
#
# En 1988, Farwell y Donchin propusieron e implementaron el primer sistema BCI, denominado “P300 Speller”, que permitía a una persona deletrear texto. En este paradigma BCI se utiliza el pico en la señal EEG que ocurre aproximadamente 300 milisegundos después de la aparición de un estímulo esperado, conocido como potencial relacionado a un evento . En el “P300 Speller”, se presenta al usuario una cuadrícula de 6×6 caracteres en una pantalla, cuyas filas y columnas parpadean al azar una por vez. El usuario debe entonces concentrarse en un carácter específico por vez y contar mentalmente cuando éste parpadea. Estos eventos generan picos ERP en la señal EEG, permitiendo así identificar el carácter por su ubicación en fila y columna.
#
# A principios de los años 90s, Jonathan Wolpaw y colegas en EEUU desarrollaron un sistema BCI que permitía al usuario controlar un cursor en una dimensión. El principio de funcionamiento de este sistema se basaba en neurofeedback, requiriendo que el usuario se entrenara para aprender a controlar la amplitud de sus ondas cerebrales tipo mu (aproximadamente entre 7 – 13 Hertz) en el área sensoriomotora de la corteza cerebral. De esta manera, el sujeto lograba generar ondas con una amplitud baja para mover el cursor hacia abajo (bottom target), o alta para mover el cursor hacia arriba (top target).
#
# A finales de la década de 1990 y principios del siglo XXI, surgieron nuevos paradigmas en las interfaces cerebro-computadora, impulsando un rápido crecimiento en el número de investigadores dedicados al desarrollo de esta tecnología. Un ejemplo notable es el paradigma de BCI basado en potenciales evocados por estímulos visuales, conocidos como SSVEPs (Steady State Visually Evoked Potentials, por sus siglas en inglés). Este enfoque ganó gran popularidad en esa época. En este paradigma, el usuario fija su atención en uno de varios patrones visuales, cada uno de los cuales parpadea a una frecuencia distinta . Así, la señal EEG de la corteza visual se sincroniza con el estímulo externo, permitiendo asociar cada patrón en la señal EEG con un comando deseado. Aunque este paradigma tiene la desventaja de causar fatiga en el usuario, ha sido utilizado con éxito en diversas aplicaciones prácticas hasta la actualidad[1].

# %% [markdown]
# **USO**

# %% [markdown]
# *1.Comunicación de pacientes con parálisis*
#
# Una interfaz cerebro–computadora (BCI), también conocida como interfaz cerebro–máquina, es una tecnología que permite controlar una computadora u otros dispositivos externos mediante la interpretación de señales cerebrales. Este tipo de sistemas ha sido evaluado principalmente en pacientes con parálisis, como aquellos con lesiones medulares cervicales o con esclerosis lateral amiotrófica. Sin embargo, su aplicación no ha sido estudiada de manera sistemática en la distrofia muscular de Duchenne (DMD), una enfermedad grave caracterizada por la ausencia de distrofina y la consecuente debilidad y atrofia muscular progresiva.
#
# En estudios recientes, se han implementado sistemas BCI basados en el paradigma P300, empleando un método de selección en dos pasos con estímulos visuales tipo parpadeo organizados por regiones. En estos experimentos, los caracteres seleccionados por los usuarios fueron registrados en línea, obteniéndose una precisión promedio del 71,6 % en pacientes con DMD durante el procedimiento de dos pasos[2].

# %% [markdown]
# *2. Control de prótesis y dispositivos robóticos*
#
# En este estudio, el BCI se utiliza como un sistema de control para una prótesis de mano, en el cual las señales electroencefalográficas (EEG) del usuario son captadas y procesadas para identificar su intención motora. A través del uso de técnicas de extracción de características y una red neuronal artificial, el sistema clasifica las señales asociadas a movimientos imaginados. Posteriormente, esta información es implementada en una plataforma FPGA, que se encarga de traducir la intención del usuario en movimientos reales de la prótesis, permitiendo así la ejecución de acciones sin necesidad de actividad muscular[3].

# %% [markdown]
# *3. Control de dispositivos (computadores, sillas de ruedas, etc.)*
#
# En este estudio, el BCI se presenta como una tecnología que permite establecer una comunicación directa entre el cerebro y dispositivos externos, con aplicaciones principalmente en la comunicación y la rehabilitación de personas con alteraciones motoras. A través del registro de la actividad cerebral, generalmente mediante EEG, el sistema extrae características relevantes de la señal y las traduce en comandos que pueden ser utilizados para interactuar con computadoras u otros dispositivos. De esta manera, el BCI no solo facilita la comunicación en pacientes con movilidad limitada, sino que también contribuye a procesos de rehabilitación neurológica al proporcionar retroalimentación en tiempo real, permitiendo al usuario modular su actividad cerebral y mejorar su desempeño funcional[4].

# %% [markdown]
# *4. Rehabilitación de pacientes con accidente cerebrovascular mediante tecnología de interfaz cerebro-computadora (BCI)*
#
# En este estudio, el BCI se emplea como una herramienta de rehabilitación para pacientes que han sufrido un accidente cerebrovascular, especialmente en fases crónicas de la enfermedad. El sistema utiliza señales electroencefalográficas (EEG) para sincronizar la actividad cerebral del paciente con movimientos periféricos, como la estimulación eléctrica funcional de los músculos. Este enfoque permite establecer una conexión entre la intención motora y la ejecución del movimiento, favoreciendo la plasticidad cerebral. Además, el estudio investiga cómo esta interacción activa, en comparación con terapias pasivas, puede generar mayores mejoras en la función motora y promover procesos de reorganización cerebral asociados a la recuperación funcional[5].

# %% [markdown]
# **Proyectos Futuros**
#
# *1. BCI portátiles y sensores flexibles (wearables)*
#
# el BCI se proyecta como una tecnología clave para el desarrollo de sistemas portátiles y de uso cotidiano, gracias al avance de sensores electrónicos cerebrales flexibles. Estos dispositivos permiten una adquisición de señales neuronales más precisa, cómoda y no invasiva, lo que abre la posibilidad de trasladar los sistemas BCI desde entornos de laboratorio hacia aplicaciones reales en el ámbito clínico. En este contexto, se plantea que los futuros desarrollos estarán orientados al monitoreo continuo de la actividad cerebral y al tratamiento de enfermedades neurológicas, facilitando una integración más directa entre el usuario y dispositivos externos. Asimismo, el artículo destaca la necesidad de cerrar la brecha entre la investigación experimental y su implementación en la práctica médica, proponiendo el uso de tecnologías más accesibles, adaptables y eficientes para su aplicación en la vida diaria[6].

# %% [markdown]
#  *2. Control de robots con BCI no invasiva*
#
#  Hasta el momento, el uso más extendido de las interfaces cerebro–computadora (BCI) ha sido el apoyo a personas con discapacidades motoras graves. Estas tecnologías se aplican, por ejemplo, en pacientes con síndrome de enclaustramiento, permitiéndoles mejorar su capacidad de comunicación, movilidad e independencia. En el campo médico, las BCI hacen posible controlar prótesis como brazos robóticos, utilizar sistemas de escritura asistida o interactuar con distintos dispositivos únicamente a partir de la actividad cerebral. A pesar de estos avances, muchas de estas aplicaciones aún se encuentran en fases experimentales o en desarrollo clínico. En contraste, en áreas como el bienestar y el entretenimiento, ya existen dispositivos comerciales, como auriculares no invasivos, que emplean retroalimentación biológica para ayudar a reducir el estrés.
#
# A futuro, se espera que surjan nuevas aplicaciones de estas tecnologías. Las BCI podrían favorecer el avance de neuroprótesis más sofisticadas, capaces de restaurar funciones sensoriales o facilitar la interacción con sistemas robóticos en tareas complejas. Además, las interfaces bidireccionales podrían permitir formas más avanzadas de comunicación, como el intercambio directo de información entre cerebros o la conexión con entornos digitales. Sin embargo, el desarrollo e implementación de estas tecnologías no solo dependerán del progreso técnico, sino también de aspectos como la aceptación social, la regulación y las implicaciones éticas[7].

# %% [markdown]
# *3.BCI aplicada a vehículos autónomos*
#
# La medición de la actividad cerebral puede proporcionar información valiosa que podría aprovecharse también para aumentar las capacidades humanas. Un ejemplo claro de esto es el proyecto Brain-to-Vehicle: Cuando el conductor de un automóvil detecta un obstáculo repentino en la carretera, su actividad cerebral muestra la intención de presionar el freno. Al decodificar estos potenciales de anticipación con una BCI, e identificar así la intención del conductor de frenar, el coche podría empezar la frenada instantáneamente, incluso antes de que se activen los músculos del conductor, lo que podría llegar a ser de gran ayuda para prevenir un accidente.
#
# En 2018, Nissan, en cooperación con Bitbrain, presentó el primer prototipo de interfaz Brain-to-Vehicle, en el que la experiencia de conducción se mejoró al anticipar las decisiones del conductor después de detectar potenciales relacionados con eventos específicos[8].

# %% [markdown]
# *4.Chip de grafeno para Parkinson y otras enfermedades*
#
# Inbrain Neuroelectronics busca restaurar la función o movilidad en pacientes con discapacidades. Han diseñado un implante de chip de grafeno que no solo rastrea la actividad cerebral, sino que también la estimula. Además, envía señales mucho más potentes en comparación con los chips metálicos típicos. Fue probado por primera vez en un paciente en 2024 y podría aplicarse a pacientes con enfermedades como el Parkinson[9].

# %% [markdown]
# *Consultar sobre actividad cerebral registrada por EEG durante movimientos e imaginación
# de movimiento de las manos y cómo se hace su análisis en sistemas BCI: Electrodos, ritmos
# cerebrales de interés*

# %% [markdown]
# La actividad cerebral registrada mediante electroencefalografía (EEG) durante el movimiento y la imaginación de movimiento de las manos se origina principalmente en la corteza motora, donde se generan señales asociadas a la planificación y ejecución del movimiento voluntario. En las interfaces cerebro-computadora (BCI), se emplea comúnmente la imaginación motora (motor imagery, MI), en la cual el usuario imagina mover la mano izquierda o derecha, produciendo patrones de actividad cerebral similares a los del movimiento real[10].
#
# Estas señales EEG se analizan en función de su contenido en frecuencia, clasificándose en bandas como delta (<4 Hz), theta (4–7 Hz), alfa (8–12 Hz), beta (12–30 Hz) y gamma (>30 Hz). En particular, la actividad alfa en la región sensoriomotora se conoce como ritmo mu, y junto con la banda beta constituye el principal foco de estudio en tareas de movimiento e imaginación motora. Diversos estudios han demostrado que durante la imaginación de movimiento de las manos se producen cambios en estas bandas, lo que permite diferenciar entre distintas tareas motoras[10].
#
# Durante estos procesos se observan fenómenos conocidos como desincronización relacionada con el evento (ERD), cuando disminuye la potencia en una banda, y sincronización relacionada con el evento (ERS), cuando aumenta. En tareas de imaginación motora de las manos, típicamente se presenta una disminución de la potencia en la banda mu y cambios en la banda beta, lo cual constituye la base para el análisis e interpretación de la intención del usuario en sistemas BCI[10].
#
# Para registrar esta actividad, se emplean electrodos ubicados sobre el cuero cabelludo siguiendo el sistema internacional 10-20, el cual estandariza las posiciones de medición. En aplicaciones de imaginación motora de las manos, los electrodos más relevantes son C3, C4 y Cz, ya que están situados sobre la corteza sensoriomotora. Estos electrodos permiten captar las variaciones de actividad cerebral asociadas al movimiento de las manos, siendo ampliamente utilizados en estudios de BCI[11].
#
# Además, existe una organización contralateral en el cerebro: la actividad registrada en el electrodo C3 está relacionada principalmente con el movimiento de la mano derecha, mientras que el electrodo C4 se asocia con la mano izquierda. Durante la imaginación motora, se observan cambios opuestos en estas regiones, lo que permite distinguir entre ambas acciones[11].
#
# En los sistemas BCI, el análisis de estas señales se basa en la identificación de cambios en los ritmos mu y beta registrados en estos electrodos, así como en la detección de patrones ERD/ERS, lo que permite clasificar la intención del usuario y traducirla en comandos. De esta manera, la imaginación de movimiento de las manos se convierte en una de las estrategias más utilizadas para el control de dispositivos mediante EEG[11].

# %% [markdown]
# *Consultar y discutir los flujos de procesamiento propuestos para estos tipos de proyectos y
# que se puedan realizar en el marco del curso*

# %% [markdown]
# Los sistemas de interfaz cerebro-computadora (BCI) basados en EEG siguen un flujo de procesamiento estructurado que permite transformar la actividad cerebral en comandos utilizables. Según la literatura, especialmente en sistemas basados en imaginación motora, este proceso se compone de varias etapas fundamentales[10].
#
# En primer lugar, se realiza la adquisición de la señal EEG, donde se registran las señales cerebrales mediante múltiples electrodos ubicados en el cuero cabelludo. Posteriormente, se lleva a cabo una etapa de preprocesamiento, en la cual se eliminan ruidos y artefactos presentes en la señal, considerando que las señales EEG son altamente no estacionarias y susceptibles a interferencias externas[10].
#
# Luego, se realiza la extracción de características, cuyo objetivo es identificar patrones relevantes dentro de la señal, como cambios en las bandas de frecuencia asociadas a la imaginación motora, especialmente en los ritmos mu y beta. En algunos sistemas, esta etapa se complementa con la selección de características, donde se eligen únicamente aquellas más representativas, con el fin de mejorar la eficiencia y precisión del sistema[10].
#
# Finalmente, se lleva a cabo la clasificación, en la cual se utilizan algoritmos para determinar la intención del usuario a partir de las características extraídas, como por ejemplo distinguir entre la imaginación de movimiento de la mano izquierda o derecha. Este proceso permite traducir la actividad cerebral en comandos que pueden ser utilizados para controlar dispositivos externos[10].
#
# Este flujo de procesamiento constituye la base de los sistemas BCI y puede ser implementado en el marco del curso mediante herramientas de análisis de señales, programación y técnicas de aprendizaje automático, permitiendo el desarrollo de aplicaciones prácticas basadas en la interpretación de señales EEG[10].

# %% [markdown]
# <p align="center">
#   <img src="flujo_procesamiento2.png" alt="Boxplot RMS" width="1000"><br>
#   <b>Figura 1.</b> Diagrama que muestra el procesamiento de señales realizado en un sistema típico de EEG basado en MI.
# </p>

# %% [markdown]
# ## **Plan de análisis**

# %% [markdown]
# *Con la información recolectada en el punto anterior proponer una metodología de
# procesamiento y análisis que permita evidenciar la diferencia en ritmos cerebrales asociados
# a las cuatro condiciones de estudio en los electrodos relevantes*

# %% [markdown]
# ### **Metodología**

# %% [markdown]
# Para evidenciar la diferencia en los ritmos cerebrales asociados a las cuatro condiciones de estudio (reposo, movimiento e imaginación de la mano izquierda y derecha), se propone la siguiente metodología, cabe aclarar que aunque los datos ya se encuentran adquiridos, la selección de canales equivalentes a los electrodos C3, C4 y Cz es fundamental para el análisis, ya que corresponden a la corteza sensoriomotora involucrada en el movimiento de las manos.

# %% [markdown]
# *1. Selección de canales (electrodos relevantes)*
#
# A partir del conjunto de datos proporcionado, se seleccionarán los canales correspondientes a la región sensoriomotora, especialmente aquellos cercanos a las posiciones C3, C4 y Cz del sistema internacional 10-20.
#
# La relevancia de estos canales radica en su vinculación funcional con las tareas motoras:
#
# * C3: se encuentra asociado al control y la activación de la mano derecha.
#
# * C4: se asocia directamente con el control de la mano izquierda.
#
# * Cz: junto con los anteriores, permite capturar y observar las diferencias espaciales y los ritmos mu/beta en la actividad cerebral durante la ejecución o imaginación motora.

# %% [markdown]
# 2. *segmentación por condiciones*
#
# Las señales EEG serán organizadas según las cuatro condiciones del experimento:
#
# * Reposo
# * Movimiento mano izquierda
# * Movimiento mano derecha
# * Imaginación motora
#
# Se trabajará con segmentos etiquetados correspondientes a cada condición.

# %% [markdown]
# 3. *Preprocesamiento*
#
# Se aplicará un filtrado pasa banda entre 8 y 30 Hz, con el fin de aislar los ritmos de interés:
#
# * Mu (8–12 Hz)
# * Beta (12–30 Hz)
#
# Esto permite eliminar ruido y centrarse en la actividad relacionada con el movimiento.

# %% [markdown]
# 4. *Cálculo de densidad espectral de potencia (PSD)*
#
# Para cada canal y condición se calculará la densidad espectral de potencia (PSD), tal como lo indica el enunciado del proyecto .
#
# A partir de esto se obtendrá:
#
# * Potencia en banda mu
# * Potencia en banda beta

# %% [markdown]
# 5. *Análisis de diferencias (ERD/ERS implícito)*
#
# Se comparará la potencia entre condiciones:
#
# * Disminución de potencia (ERD (activación))
# * Aumento de potencia (ERS)
#
# Se espera observar:
#
# * Cambios en C3 y C4 según la mano utilizada
# * Diferencias claras frente a la condición de reposo

# %% [markdown]
# 6. *Organización de resultados*
#
# Los resultados se almacenarán en un dataframe, incluyendo:
#
# * Sujeto
# * Condición
# * Canal
# * Potencia en cada banda
#
# Esto permitirá realizar comparaciones posteriores.

# %% [markdown]
# 7. *Análisis estadístico y visualización*
#
# Se utilizarán:
#
# * Gráficas (boxplots, barras, PSD)
# * Estadística descriptiva
#
# Para evidenciar diferencias entre:
#
# * Condiciones
# * Electrodos

# %% [markdown]
# <p align="center">
#   <img src="esquema_flujo.png" alt="Boxplot RMS" width="1000"><br>
#   <b>Figura 2.</b> Metodología adquisición de señal
# </p>

# %% [markdown]
# *Proponer las hipótesis posibles y las herramientas a usar para probar dichas hipótesis*
#
# ### *Hipótesis*
#
#  1. Diferencias en PSD entre condiciones (ritmos mu y beta)
#
# H₀(Nula)
#
# No existen diferencias significativas en la densidad espectral de potencia (PSD) en las bandas mu (8–12 Hz) y beta (12–30 Hz) entre las cinco condiciones (reposo, movimiento real e imaginación de la mano izquierda y derecha) en los electrodos C3, C4 y Cz.
#
# H₁(Alternativa)
#
# Existen diferencias significativas en la PSD de las bandas mu y beta entre al menos dos condiciones, siendo la condición de reposo la de mayor potencia, y las condiciones de movimiento e imaginación las de menor potencia (ERD).
#
#
# 2. *Lateralización hemisférica (C3 vs C4)*
#
# H₀(Nula)
# No hay diferencia significativa en la PSD entre los electrodos C3 y C4 durante las tareas de movimiento o imaginación de la mano derecha vs. izquierda.
#
# H₁(Alternativa)
# Durante el movimiento o imaginación de la mano derecha, C3 mostrará mayor ERD (menor PSD) que C4, y viceversa para la mano izquierda, evidenciando organización contralateral.
#
# 3. *Movimiento real vs. imaginación motora*
#
# H₀(Nula)
# No hay diferencia significativa en la PSD de las bandas mu y beta entre la condición de movimiento real y la imaginación motora de la misma mano.
#
# H₁(Alternativa)
# El movimiento real produce una mayor supresión de potencia (ERD más profundo) en mu y beta que la imaginación motora, aunque ambas condiciones son distinguibles del reposo
#
# ### *Herramientas*
#
# *H1 — Diferencias de potencia entre las 5 condiciones*
#
# Se calculará la PSD de cada condición. Posteriormente, se verificará la normalidad de los datos mediante la prueba de Shapiro-Wilk. En caso de que los datos sigan una distribución normal, se aplicará un ANOVA de una vía; de lo contrario, se empleará la prueba de Kruskal-Wallis. Si se obtiene un resultado significativo (p < 0.05), se realizarán comparaciones post-hoc mediante Tukey o Dunn para identificar qué pares de condiciones difieren entre sí. Finalmente, los resultados se presentarán mediante boxplots y curvas PSD.
#
# *H2 — Lateralización hemisférica entre C3 y C4*
#
# Se calculará la PSD de los electrodos C3 y C4 para cada condición. Dado que las mediciones provienen del mismo sujeto, se aplicará una prueba pareada: Wilcoxon en caso de no normalidad, o t-test pareado si se confirma normalidad. La prueba se realizará de forma unilateral, considerando la dirección esperada de la activación contralateral. Se calculará además el índice de lateralización como medida complementaria. Los resultados se presentarán mediante gráficas de barras comparando C3, C4 y Cz por condición.
#
# *H3 — Movimiento real vs. imaginación motora*
#
# Se calcularán y compararán las PSD del movimiento real y de la imaginación motora para la misma mano. La comparación se llevará a cabo mediante la prueba de Mann-Whitney U, o t-test independiente si se confirma normalidad, aplicada de forma unilateral dado que se espera un ERD más profundo en el movimiento real. Se calculará el tamaño del efecto mediante Cohen's d para cuantificar la magnitud de la diferencia. Los resultados se visualizarán superponiendo las curvas PSD de ambas condiciones.

# %% [markdown]
# ## **Programación**

# %% [markdown]
# *Crear una función que reciba una señal de EEG y le aplique el flujo de procesamiento
# definido. Para el informe mostrar cómo cambia la señal en diferentes fases del
# procesamiento*

# %% [markdown]
# Para el desarrollo del análisis de señales EEG, el primer paso consiste en la importación de las librerías necesarias, las cuales permiten realizar el procesamiento, la visualización y el análisis espectral de los datos. Estas herramientas son fundamentales porque el flujo de trabajo requiere operaciones de manipulación de señales, filtrado digital, segmentación en épocas y cálculo de la densidad espectral de potencia (PSD), propias del análisis para la señal EEG.
#
# En particular, se utilizan librerías especializadas como MNE para el manejo de señales EEG en formato estándar, NumPy para el procesamiento numérico eficiente, SciPy para el análisis en frecuencia, y Matplotlib para la visualización de las distintas fases del procesamiento. Estas bibliotecas constituyen la base computacional que permite implementar el  análisis propuesto en la metodología.

# %%
import os
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mne
from scipy.signal import detrend, freqz
import mne.filter
import mne.viz

# %% [markdown]
# Antes de iniciar el procesamiento de las señales EEG, se realiza una etapa de caracterización del conjunto de datos con el fin de comprender sus propiedades temporales y estructurales. Esta fase permite establecer parámetros fundamentales como la frecuencia de muestreo, el número de canales, la cantidad total de muestras y la duración de las señales.
#
# Para ello, se selecciona un archivo representativo de la base de datos y se extraen los datos asociados mediante la estructura estándar de MNE. En particular, se obtiene la frecuencia de muestreo (fs), el número de canales registrados, y el número total de muestras por registro. A partir de estos valores se calcula la duración total de la señal mediante la relación entre el número de muestras y la frecuencia de muestreo.
#
# Adicionalmente, se realiza un análisis de los eventos contenidos en las anotaciones del EEG, con el objetivo de estimar la duración promedio de los segmentos asociados a cada condición experimental (T0, T1 y T2). Este análisis permite entender la distribución temporal de las tareas dentro del experimento y validar la consistencia de los registros.
#
# En conjunto, esta etapa proporciona una visión general del dataset, asegurando que los parámetros de adquisición sean adecuados para el posterior procesamiento, filtrado y análisis espectral de las señales.

# %%
base_path = 'Lab_EEG_Imagineria' #Esta es nuestra carpeta donde estan todos los sujetos (dataset de OpenNeuro).

_primer_sujeto  = sorted([s for s in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, s))])[0]#Obtiene la primera carpeta del primer sujeto.
_primer_archivo = sorted([f for f in os.listdir(os.path.join(base_path, _primer_sujeto)) if f.endswith('.set')])[0]#dentro del sujeto obtiene el primer archivo .set
_raw_ref        = mne.io.read_raw_eeglab(os.path.join(base_path, _primer_sujeto, _primer_archivo), preload=True, verbose=False)#lee el archivo EEG y lo carga completamente en memoria.

fs             = _raw_ref.info['sfreq'] #frecuencia de muestreo.
ch_names       = _raw_ref.ch_names #nombre de canales (electrodos).
n_canales      = len(ch_names) #número total de canales.
n_muestras     = _raw_ref.n_times # número total de muestras (puntos en el tiempo).
duracion_total = n_muestras / fs #duración total del registro en segundos. 

_events, _event_id = mne.events_from_annotations(_raw_ref, verbose=False) #convierte las anotaciones del EEG en eventos utilizables.
_tiempos_eventos   = _events[:, 0] / fs #extrae el tiempo de cada evento en segundos.
_tipos_eventos     = _events[:, 2] #extrae tipo de código de cada evento (T0,T1,T2)

duracion_tramos = {} #En este diccionario se guardan los resultados.
for nombre, codigo in _event_id.items(): #Este for recorre cada tipo de evento T0,T2,T1.
    # Filtra solo eventos relevantes del experimento:
    # T0 = reposo
    # T1 = movimiento e imaginación motora (ej: mano izquierda, ambos puños)
    # T2 = movimiento e imaginación motora (ej: mano derecha, ambos pies)
    if not any(t in nombre for t in ['T0', 'T1', 'T2']):
        continue
    _idx      = np.where(_tipos_eventos == codigo)[0] # Encuentra los índices donde ocurre ese evento.

    _tiempos  = _tiempos_eventos[_idx] # Obtiene los tiempos en que ocurre ese evento.
    _durs     = np.diff(_tiempos) # Calcula la duración entre eventos consecutivos
    # (diferencia de tiempo entre un evento y el siguiente)
    duracion_tramos[nombre] = {
        'promedio': np.mean(_durs),
        'n_tramos': len(_durs)
    }

print(f"fs             = {fs} Hz")  # Frecuencia de muestreo
print(f"canales        = {n_canales}") # Número de electrodos
print(f"muestras       = {n_muestras}") # Número de puntos de la señal
print(f"duración total = {duracion_total:.2f} s ({duracion_total/60:.2f} min)")
for nombre, info in duracion_tramos.items(): # Imprime duración promedio por tipo de evento

    print(f"{nombre}: promedio = {info['promedio']:.2f} s | tramos = {info['n_tramos']}")
# Out:
# fs             = 160.0 Hz
# canales        = 64
# muestras       = 20000
# duración total = 125.00 s (2.08 min)
# TASK4T0: promedio = 8.30 s | tramos = 14
# TASK4T1: promedio = 17.98 s | tramos = 6
# TASK4T2: promedio = 15.41 s | tramos = 7

# %% [markdown]
# Este resultado demuestra como la tarea 4 dura aproximadamente 2 minutos, confirmando la información suministrada por OpenNeuro.

# %% [markdown]
# Primero exploramos la estructura de la base de datos para identificar cómo están organizados los archivos por sujeto y verificar que los registros EEG estén en formato compatible. Esto nos permite asegurar que el pipeline pueda recorrer automáticamente toda la base de datos sin errores.

# %%
import os # Librería para interactuar con el sistema de archivos
base_path = 'Lab_EEG_Imagineria' # Carpeta principal donde está el dataset EEG (OpenNeuro)
sujeto = sorted(os.listdir(base_path))[0] # Obtiene el nombre del primer sujeto (carpeta)
# sorted(...) ordena alfabéticamente (ej: sub-001, sub-002, ...)
archivos = sorted(os.listdir(os.path.join(base_path, sujeto))) # Lista todos los archivos dentro de la carpeta de ese sujeto
print(archivos)# Imprime la lista de archivos
# Out:
# ['sub-001_task-motion_run-10_eeg.set', 'sub-001_task-motion_run-11_eeg.set', 'sub-001_task-motion_run-12_eeg.set', 'sub-001_task-motion_run-13_eeg.set', 'sub-001_task-motion_run-14_eeg.set', 'sub-001_task-motion_run-1_eeg.set', 'sub-001_task-motion_run-2_eeg.set', 'sub-001_task-motion_run-3_eeg.set', 'sub-001_task-motion_run-4_eeg.set', 'sub-001_task-motion_run-5_eeg.set', 'sub-001_task-motion_run-6_eeg.set', 'sub-001_task-motion_run-7_eeg.set', 'sub-001_task-motion_run-8_eeg.set', 'sub-001_task-motion_run-9_eeg.set']

# %% [markdown]
# Este resultado da cuenta de que cada sujeto elabora 14 series experimentales.

# %% [markdown]
# Se implementa una función para extraer el número de run desde el nombre del archivo, ya que este identifica la condición experimental de adquisición. Esto permite clasificar correctamente cada señal dentro del experimento.

# %%
def obtener_num_run(nombre_archivo):
    """Extrae solo el número de run del nombre del archivo-  Ejemplo esperado: sub-001_task-motor_run-03_eeg.set → devuelve 3"""
    #En este caso RUN 3 seria= Abrir y cerrar puño izquierdo/ puño derecho. (EJECUTANDO LA TAREA 1)
    try:
        run_str = nombre_archivo.split('run-')[1].split('_')[0]
        # Divide el nombre usando 'run-' y toma la parte después
        # Ej: "sub-001_run-03_eeg.set" → ["sub-001_", "03_eeg.set"]
        # Luego corta hasta el siguiente "_" para aislar el número
        # "03_eeg.set" → "03"
        return int(float(run_str))
            # Convierte a número entero (como "03" o "3.0")

    except (IndexError, ValueError):
        # Si el formato no coincide o no se puede convertir,
        # devuelve -1 como indicador de error
        return -1

# %% [markdown]
# Para permitir una correcta interpretación de las señales EEG dentro del contexto del experimento, se implementa una función de decodificación de eventos. Esta función tiene como objetivo traducir los códigos de eventos presentes en los registros EEG , considerando tanto el tipo de ejecución (real o imaginada) como la condición motora asociada.
#
# La base de datos contiene distintos “runs” experimentales, los cuales definen el tipo de tarea realizada por el sujeto. En este caso, algunos runs corresponden a movimientos reales y otros a imaginería motora, incluyendo tareas como movimiento de mano izquierda, mano derecha, ambos puños o ambos pies.
#
# A partir de esta información, la función asigna una etiqueta semántica a cada evento (T0, T1 y T2), donde:
#
# T0 corresponde a reposo
# T1 y T2 representan distintas acciones motoras dependiendo del run, se diferencia entre ejecución real e imaginación motora.
#
# De esta manera, cada segmento de la señal EEG puede ser asociado a una condición experimental específica, lo cual es fundamental para el análisis posterior de la densidad espectral de potencia y la comparación entre estados cerebrales.
#
# En caso de que el evento o el run no cumplan con los patrones esperados, la función retorna la categoría “Desconocido”, garantizando así el manejo de datos inconsistentes sin interrumpir el flujo del procesamiento.

# %%
def interpretar_evento(evento, num_run):
    """
    Traduce el código de evento al significado real según el número de run.

    Runs 3,7,11  → Movimiento Real mano izq/der
    Runs 4,8,12  → Imaginería Motora mano izq/der
    Runs 5,9,13  → Movimiento Real ambos puños/pies
    Runs 6,10,14 → Imaginería Motora ambos puños/pies

    T0 = Reposo (siempre)
    T1 = Mano Izquierda o Ambos Puños
    T2 = Mano Derecha o Ambos Pies
    """
    if num_run in [3, 7, 11]:
        tipo_accion = 'Real'
        lateralidad = {'T0': 'Reposo', 'T1': 'Mano_Izquierda', 'T2': 'Mano_Derecha'}
    elif num_run in [4, 8, 12]:
        tipo_accion = 'Imaginado'
        lateralidad = {'T0': 'Reposo', 'T1': 'Mano_Izquierda', 'T2': 'Mano_Derecha'}
    elif num_run in [5, 9, 13]:
        tipo_accion = 'Real'
        lateralidad = {'T0': 'Reposo', 'T1': 'Ambos_Punos', 'T2': 'Ambos_Pies'}
    elif num_run in [6, 10, 14]:
        tipo_accion = 'Imaginado'
        lateralidad = {'T0': 'Reposo', 'T1': 'Ambos_Punos', 'T2': 'Ambos_Pies'}
    else:
        return 'Desconocido'

    for t in ['T0', 'T1', 'T2']:
        if evento.endswith(t):
            if t == 'T0':
                return 'Reposo'
            return f'{lateralidad[t]}_{tipo_accion}'

    return 'Desconocido'

# %% [markdown]
# Para el análisis de las señales EEG, se implementa una función principal encargada de aplicar un flujo completo de preprocesamiento, segmentación y preparación de los datos para su análisis espectral. Este flujo permite transformar señales crudas en representaciones útiles para el estudio de la actividad cerebral asociada a tareas motoras e imaginería motora.
#
# Inicialmente, se realiza la selección de los canales de interés correspondientes a la región sensoriomotora (C3, C4 y Cz), los cuales están directamente relacionados con la actividad cortical involucrada en el control y planificación del movimiento. Esta selección permite focalizar el análisis en las áreas cerebrales más relevantes para la detección de patrones asociados a la ejecución e imaginación motora.
#
# Posteriormente, se realiza una etapa de visualización de la señal original, con el fin de observar su comportamiento antes del procesamiento y establecer una referencia de comparación. A continuación, se aplica una corrección de tendencia (detrend), la cual elimina componentes de baja frecuencia y desplazamientos en la señal que no corresponden a actividad neurofisiológica relevante, evitando así sesgos en el análisis espectral posterior.
#
# En la tercera fase, se aplica un filtrado pasa banda entre 7 y 30 Hz, con el objetivo de aislar los ritmos cerebrales de interés, específicamente las bandas mu (8–12 Hz) y beta (12–30 Hz), las cuales están asociadas a procesos de planificación motora, ejecución de movimiento y fenómenos de sincronización/desincronización cortical (ERD/ERS)[10].
#
# El filtrado se implementa mediante un filtro FIR (Finite Impulse Response) diseñado con el método de ventana (firwin), el cual es ampliamente utilizado en el procesamiento de señales EEG debido a sus propiedades de estabilidad numérica y su capacidad de mantener una respuesta de fase lineal. Estas características son fundamentales en el análisis de señales neurofisiológicas, ya que evitan distorsiones temporales en la actividad cerebral registrada. A diferencia de los filtros IIR (Infinite Impulse Response), los filtros FIR no presentan realimentación, lo que garantiza estabilidad numérica, ausencia de inestabilidades y un comportamiento más controlado en el dominio de la frecuencia [12,13,15].
#
# Adicionalmente, el orden del filtro FIR es determinado automáticamente por la librería MNE-Python en función de la frecuencia de muestreo y los parámetros de diseño del filtro. Este orden controla el compromiso entre selectividad en frecuencia y costo computacional: un mayor orden permite una mejor separación entre bandas, pero incrementa la complejidad del filtrado y el retardo temporal. Por esta razón, su cálculo automático garantiza un balance adecuado entre precisión espectral y eficiencia del procesamiento[13].
#
# Durante esta etapa también se realiza una comparación visual entre la señal original, la señal filtrada y las componentes eliminadas, así como el análisis de la respuesta en frecuencia del filtro mediante su diagrama de Bode. Este análisis permite validar el comportamiento del filtro en el dominio frecuencial, verificando la correcta conservación de la banda de interés (8–30 Hz), la atenuación de componentes fuera de banda y la respuesta de fase aproximadamente lineal, lo cual es fundamental para preservar la integridad temporal de los eventos EEG[13].
#
# Finalmente, se realiza la segmentación de la señal en épocas utilizando los eventos anotados en el registro EEG, considerando únicamente las condiciones relevantes del experimento (T0, T1 y T2). Esta segmentación permite estructurar la señal en ensayos independientes asociados a cada tarea experimental, lo cual es un paso fundamental para el análisis posterior de la densidad espectral de potencia y la comparación entre condiciones cognitivas.
#
# Como salida, la función retorna tanto las épocas segmentadas como las señales intermedias de cada fase del procesamiento, lo que permite evidenciar el efecto de cada etapa sobre la señal original y garantiza la trazabilidad completa del flujo de procesamiento aplicado.

# %%
def procesar_eeg_completo(raw, sujeto_id, nombre_archivo, tipo_tarea, mostrar_graficas=True):

    canales_interes = ['C3', 'C4', 'Cz']
    picks = [ch for ch in raw.ch_names if ch.replace('.', '') in canales_interes]

    raw_orig = raw.copy().pick(picks)
    raw_res  = raw.copy().pick(picks)

    # FASE 1: Señal Original 
    if mostrar_graficas:
        raw_orig.plot(
            title=f"Fase 1: Señal Original – {sujeto_id}",
            duration=15, scalings={'eeg': 50e-6}, show=False
        )
        plt.tight_layout()
        plt.show()

    #  FASE 2: Detrend 
    data_original = raw_res.get_data().copy()
    data_detrend  = mne.filter.detrend(data_original, order=0, axis=1)
    raw_res._data = data_detrend.copy()

    if mostrar_graficas:
        sfreq = raw_res.info['sfreq']
        n_pts = int(5 * sfreq)
        tiempo = np.arange(n_pts) / sfreq
        canal  = raw_res.ch_names[0]

        datos_orig    = data_original[0, :n_pts] * 1e6
        datos_detrend = data_detrend[0, :n_pts]  * 1e6

        fig, axes = plt.subplots(2, 1, figsize=(14, 6), sharex=True)
        fig.suptitle(f'Fase 2: Detrend – Canal {canal.replace(".", "")} ({sujeto_id})')
        axes[0].plot(tiempo, datos_orig,    color='steelblue')
        axes[0].set_title('Señal Original')
        axes[1].plot(tiempo, datos_detrend, color='darkorange')
        axes[1].set_title('Señal sin tendencia (Detrend)')
        for ax in axes:
            ax.set_ylabel('Amplitud (µV)')
            ax.grid(True, alpha=0.3)
        axes[1].set_xlabel('Tiempo (s)')
        plt.tight_layout()
        plt.show()

    # FASE 3: Filtrado (7–30 Hz) 
    raw_res.filter(l_freq=7, h_freq=30, fir_design='firwin', verbose=False)
    data_filtrada = raw_res.get_data().copy()

    if mostrar_graficas:
        sfreq = raw_res.info['sfreq']
        n_pts = int(5 * sfreq)
        tiempo = np.arange(n_pts) / sfreq
        canal  = raw_res.ch_names[0]

        datos_detrend_plot = data_detrend[0, :n_pts] * 1e6
        datos_filt_plot    = data_filtrada[0, :n_pts] * 1e6

        fig, axes = plt.subplots(3, 1, figsize=(14, 8), sharex=True)
        fig.suptitle(f'Fase 3: Filtrado (7–30 Hz) – Canal {canal.replace(".", "")} ({sujeto_id})')
        axes[0].plot(tiempo, datos_detrend_plot, color='darkorange')
        axes[0].set_title('Señal Detrend (entrada al filtro)')
        axes[1].plot(tiempo, datos_filt_plot,    color='green')
        axes[1].set_title('Señal Filtrada (7–30 Hz)')
        axes[2].plot(tiempo, datos_detrend_plot - datos_filt_plot, color='red')
        axes[2].set_title('Componentes eliminadas por el filtro')
        for ax in axes:
            ax.set_ylabel('Amplitud (µV)')
            ax.grid(True, alpha=0.3)
        axes[2].set_xlabel('Tiempo (s)')
        plt.tight_layout()
        plt.show()

        filt_coefs = mne.filter.create_filter(
            data=None, sfreq=sfreq,
            l_freq=7, h_freq=30,
            method='fir', fir_design='firwin'
        )
        print(f"\nOrden del filtro FIR: {len(filt_coefs) - 1}")
        mne.viz.plot_filter(filt_coefs, sfreq, flim=(0.1, 50), fscale='log')
        plt.show()

        w, h = freqz(filt_coefs, worN=8192, fs=sfreq)
        fig, axes = plt.subplots(2, 1, figsize=(12, 6), sharex=True)
        fig.suptitle('Diagrama de Bode – Filtro FIR (7–30 Hz)')
        axes[0].plot(w, 20 * np.log10(np.abs(h) + 1e-10))
        axes[0].axvspan(7, 30, alpha=0.10, color='blue',  label='Filtro (7–30 Hz)')
        axes[0].axvspan(8, 30, alpha=0.15, color='green', label='Interés (8–30 Hz)')
        axes[0].axhline(-3, linestyle='--', color='gray', label='-3 dB')
        axes[0].set_ylabel('Magnitud (dB)')
        axes[0].legend()
        axes[0].grid(True, alpha=0.3)
        fase = np.unwrap(np.angle(h)) * 180 / np.pi
        axes[1].plot(w, fase)
        axes[1].axvspan(7, 30, alpha=0.10, color='blue')
        axes[1].axvspan(8, 30, alpha=0.15, color='green')
        axes[1].set_ylabel('Fase (°)')
        axes[1].set_xlabel('Frecuencia (Hz)')
        axes[1].grid(True, alpha=0.3)
        axes[0].set_xlim(0, 45)
        axes[1].set_xlim(0, 45)
        plt.tight_layout()
        plt.show()

    # --- FASE 4: Segmentación en épocas ---
    events, event_id = mne.events_from_annotations(raw_res, verbose=False)

    event_id_filtrado = {
        k: v for k, v in event_id.items()
        if k.endswith(('T0', 'T1', 'T2'))
    }

    if len(events) == 0 or len(event_id_filtrado) == 0:
        return None, {}

    epochs = mne.Epochs(
        raw_res, events, event_id=event_id_filtrado,
        tmin=-0.5, tmax=2.0,
        baseline=(-0.5, 0),
        preload=True,
        verbose=False
    )

    if len(epochs) == 0:
        return None, {}

    fases = {
        'original': data_original,
        'detrend':  data_detrend,
        'filtrada': data_filtrada,
        'ch_names': [ch.replace('.', '') for ch in raw_res.ch_names],
        'sfreq':    raw_res.info['sfreq']
    }

    return epochs, fases

# %% [markdown]
# *Para cada señal procesada obtener la densidad espectral de potencia en un conjunto
# de canales de interés para las diferentes bandas en las cuales se divide el EEG de
# acuerdo a la revisiones previas*

# %% [markdown]
# El análisis cuantitativo de la señal EEG se fundamenta en el cálculo de la densidad espectral de potencia (PSD) mediante la transformada de Fourier utilizando el método de Welch, el cual permite estimar de manera robusta la distribución de energía de la señal en el dominio frecuencial.
#
# De acuerdo con la literatura, este enfoque es ampliamente utilizado en el análisis de EEG debido a su estabilidad frente al ruido y su capacidad para obtener estimaciones consistentes de la potencia espectral en diferentes bandas de frecuencia.
#
# En este trabajo, la señal EEG se divide en bandas de interés neurofisiológico, específicamente mu (8–12 Hz) y beta (12–30 Hz), las cuales han sido ampliamente asociadas con procesos de activación motora, planificación del movimiento y fenómenos de sincronización/desincronización cortical.
#
# Siguiendo la metodología reportada en estudios previos, las medidas de potencia se normalizan dividiendo la potencia de cada banda por la suma de la potencia total dentro del rango de interés (mu + beta). Esta normalización permite obtener una potencia relativa, reduciendo la influencia de variaciones intersujeto y diferencias en amplitud absoluta de la señal[16].
#
# Este procedimiento es consistente con trabajos previos en análisis EEG cuantitativo, donde la normalización espectral se utiliza para mejorar la comparabilidad entre sujetos y condiciones experimentales, así como para enfocar el análisis en la distribución relativa de energía entre bandas funcionalmente relevantes.

# %%
def psd_todas_las_bandas(epochs, sujeto_id, tipo_tarea, mostrar_graficas=True):

    if epochs is None or len(epochs) == 0:
        return {}

    bandas_interes = {
        'Mu':   (8,  13),
        'Beta': (13, 30),
    }

    try:
        # fmin=7 para no mostrar el ruido de baja frecuencia
        psds_obj = epochs.compute_psd(
            method='welch',
            fmin=7,
            fmax=30,
            n_fft=512, n_per_seg=256, n_overlap=128,
            verbose=False
        )
    except Exception as e:
        print(f"[ERROR] PSD computation failed: {e}")
        return {}

    if psds_obj.get_data().size == 0:
        return {}

    freqs    = psds_obj.freqs
    psd_mean = psds_obj.get_data().mean(axis=0)  # (n_canales, n_freqs)

    if mostrar_graficas:
        colores = {'Mu': '#e15759', 'Beta': '#76b7b2'}
        fig, ax = plt.subplots(figsize=(12, 5))
        for i, ch_name in enumerate(epochs.ch_names):
            #  plot normal, no semilogy, porque los valores son relativos (0 a 1)
            ax.plot(freqs, psd_mean[i],
                    label=ch_name.replace('.', ''), linewidth=1.5)
        for banda_nom, (f_min, f_max) in bandas_interes.items():
            ax.axvspan(f_min, f_max, alpha=0.15,
                       color=colores.get(banda_nom, 'gray'),
                       label=f'{banda_nom} ({f_min}–{f_max} Hz)')
        ax.set_xlabel('Frecuencia (Hz)')
        ax.set_ylabel('Densidad Espectral (µV²/Hz)')  
        ax.set_title(f'PSD – Mu & Beta | {tipo_tarea} ({sujeto_id})')
        ax.legend(fontsize=8, ncol=2)
        ax.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()

    resultado = {}
    for i, ch_name in enumerate(epochs.ch_names):
        ch = ch_name.replace('.', '')

        #Total = solo Mu + Beta (8–30 Hz)
        potencia_total = np.sum(psd_mean[i])  # ya que fmin=8 y fmax=30

        for banda_nom, (f_min, f_max) in bandas_interes.items():
            idx_banda = np.logical_and(freqs >= f_min, freqs <= f_max)
            potencia_banda = np.sum(psd_mean[i, idx_banda])
            # Potencia relativa 
            resultado[f'{banda_nom}_{ch}'] = potencia_banda / potencia_total

    return resultado

# %% [markdown]
# *Crear una rutina que aplique sobre todos los archivos de la base de datos las rutinas
# anteriores y almacene los resultados en un dataframe donde se pueda discriminar
# nombre sujeto, la condición evaluada y la densidad espectral de potencia obtenida*

# %% [markdown]
# Para el procesamiento global de la base de datos EEG, se implementa una rutina automatizada encargada de recorrer todos los sujetos y registros disponibles, con el fin de aplicar de manera consistente el flujo de preprocesamiento definido previamente.
#
# Esta función permite integrar en un único procedimiento las etapas de carga de datos, selección de canales, preprocesamiento, segmentación en épocas y cálculo de la densidad espectral de potencia (PSD), garantizando la homogeneidad en el tratamiento de todas las señales.
#
# Cada archivo EEG es procesado individualmente, y posteriormente segmentado en eventos correspondientes a las condiciones experimentales (T0, T1 y T2). A cada segmento se le aplica el cálculo de la PSD mediante el método de Welch, obteniendo la potencia en las bandas de interés (mu y beta) para los canales seleccionados.
#
# Los resultados obtenidos se almacenan en un dataframe estructurado, en el cual cada fila representa una observación correspondiente a un sujeto, una condición experimental y un evento específico. Las columnas incluyen la identificación del sujeto, el número de run, la condición evaluada y las potencias espectrales por banda y canal.
#
# Esta organización permite realizar análisis comparativos entre sujetos y condiciones, facilitando el estudio de diferencias en la actividad cerebral asociada a tareas motoras e imaginería motora, y asegurando la trazabilidad completa del procesamiento aplicado a cada señal.

# %%
def construir_dataframe_completo(base_path, incluir_baseline=False):

    filas = []

    if not os.path.exists(base_path):
        print(f"[ERROR] No se encontró la carpeta: {base_path}")
        return pd.DataFrame()

    sujetos = sorted([s for s in os.listdir(base_path)
                      if os.path.isdir(os.path.join(base_path, s))])

    primer_sujeto = sujetos[0] if sujetos else None
    primer_archivo_mostrado = False

    for sujeto in sujetos:
        ruta_sujeto = os.path.join(base_path, sujeto)

        for archivo in sorted(os.listdir(ruta_sujeto)):
            if not archivo.endswith('.set'):
                continue

            num_run = obtener_num_run(archivo)

            if not incluir_baseline and num_run in [1, 2]:
                continue

            mostrar = (sujeto == primer_sujeto and not primer_archivo_mostrado)

            try:
                ruta_completa = os.path.join(ruta_sujeto, archivo)
                raw = mne.io.read_raw_eeglab(ruta_completa, preload=True, verbose=False)

                with warnings.catch_warnings():
                    warnings.simplefilter("ignore")
                    epochs, fases = procesar_eeg_completo(
                        raw, sujeto, archivo, '',
                        mostrar_graficas=mostrar
                    )

                if epochs is None:
                    print(f"[INFO] Sin epochs válidos en {sujeto}/{archivo}")
                    continue

                if mostrar:
                    primer_archivo_mostrado = True

                # Una fila por cada evento (T0, T1, T2)
                for evento in epochs.event_id.keys():
                    epochs_evento = epochs[evento]

                    if len(epochs_evento) == 0:
                        continue

                    tarea_interpretada = interpretar_evento(evento, num_run)

                    potencias = psd_todas_las_bandas(
                        epochs_evento, sujeto, evento,
                        mostrar_graficas=mostrar
                    )

                    if not potencias:
                        continue

                    filas.append({
                        'Registro':   sujeto,
                        'Run':        num_run,
                        'Evento_Raw': evento,
                        'Tarea':      tarea_interpretada,
                        **potencias
                    })

            except Exception as e:
                print(f"[SKIP] {sujeto}/{archivo}: {type(e).__name__} – {e}")
                continue

    df = pd.DataFrame(filas)
    if df.empty:
        print("[INFO] DataFrame vacío, no se generaron resultados.")
        return df

    cols_fijas  = ['Registro', 'Run', 'Evento_Raw', 'Tarea']
    cols_bandas = sorted([c for c in df.columns if c not in cols_fijas])
    return df[cols_fijas + cols_bandas]

# %%
# EJECUCIÓN

base_path   = 'Lab_EEG_Imagineria'
df_completo = construir_dataframe_completo(base_path)
print(df_completo.to_string())
df_completo.to_csv('resultados_completos.csv', index=False)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# No data specified. Sanity checks related to the length of the signal relative to the filter order will be skipped.
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 265 samples (1.656 s)
#
#
# Orden del filtro FIR: 264
#     Registro  Run Evento_Raw                     Tarea   Beta_C3   Beta_C4   Beta_Cz     Mu_C3     Mu_C4     Mu_Cz
# 0      sub_1   10    TASK4T0                    Reposo  0.483472  0.449185  0.526053  0.516528  0.550815  0.473947
# 1      sub_1   10    TASK4T1     Ambos_Punos_Imaginado  0.516328  0.534641  0.571814  0.483672  0.465359  0.428186
# 2      sub_1   10    TASK4T2      Ambos_Pies_Imaginado  0.503169  0.489489  0.556347  0.496831  0.510511  0.443653
# 3      sub_1   11    TASK1T0                    Reposo  0.432170  0.450900  0.438972  0.567830  0.549100  0.561028
# 4      sub_1   11    TASK1T1       Mano_Izquierda_Real  0.509428  0.577884  0.538314  0.490572  0.422116  0.461686
# 5      sub_1   11    TASK1T2         Mano_Derecha_Real  0.515564  0.552018  0.575997  0.484436  0.447982  0.424003
# 6      sub_1   12    TASK2T0                    Reposo  0.450559  0.487786  0.487281  0.549441  0.512214  0.512719
# 7      sub_1   12    TASK2T1  Mano_Izquierda_Imaginado  0.522133  0.529218  0.544079  0.477867  0.470782  0.455921
# 8      sub_1   12    TASK2T2    Mano_Derecha_Imaginado  0.565034  0.588362  0.569196  0.434966  0.411638  0.430804
# 9      sub_1   13    TASK3T0                    Reposo  0.507320  0.503987  0.566705  0.492680  0.496013  0.433295
# 10     sub_1   13    TASK3T1          Ambos_Punos_Real  0.419059  0.460176  0.440761  0.580941  0.539824  0.559239
# 11     sub_1   13    TASK3T2           Ambos_Pies_Real  0.523674  0.452836  0.521984  0.476326  0.547164  0.478016
# 12     sub_1   14    TASK4T0                    Reposo  0.469828  0.522810  0.587019  0.530172  0.477190  0.412981
# 13     sub_1   14    TASK4T1     Ambos_Punos_Imaginado  0.378924  0.430196  0.409144  0.621076  0.569804  0.590856
# 14     sub_1   14    TASK4T2      Ambos_Pies_Imaginado  0.443584  0.514027  0.535482  0.556416  0.485973  0.464518
# 15     sub_1    3    TASK1T0                    Reposo  0.520157  0.537211  0.492853  0.479843  0.462789  0.507147
# 16     sub_1    3    TASK1T1       Mano_Izquierda_Real  0.507625  0.485968  0.560607  0.492375  0.514032  0.439393
# 17     sub_1    3    TASK1T2         Mano_Derecha_Real  0.620406  0.591003  0.612542  0.379594  0.408997  0.387458
# 18     sub_1    4    TASK2T0                    Reposo  0.541289  0.547831  0.546798  0.458711  0.452169  0.453202
# 19     sub_1    4    TASK2T1  Mano_Izquierda_Imaginado  0.545154  0.519441  0.520508  0.454846  0.480559  0.479492
# 20     sub_1    4    TASK2T2    Mano_Derecha_Imaginado  0.611795  0.529150  0.556712  0.388205  0.470850  0.443288
# 21     sub_1    5    TASK3T0                    Reposo  0.569214  0.491572  0.562424  0.430786  0.508428  0.437576
# 22     sub_1    5    TASK3T1          Ambos_Punos_Real  0.519249  0.493137  0.534539  0.480751  0.506863  0.465461
# 23     sub_1    5    TASK3T2           Ambos_Pies_Real  0.512102  0.489007  0.504478  0.487898  0.510993  0.495522
# 24     sub_1    6    TASK4T0                    Reposo  0.446491  0.394526  0.507711  0.553509  0.605474  0.492289
# 25     sub_1    6    TASK4T1     Ambos_Punos_Imaginado  0.412675  0.460687  0.479785  0.587325  0.539313  0.520215
# 26     sub_1    6    TASK4T2      Ambos_Pies_Imaginado  0.440836  0.439337  0.467052  0.559164  0.560663  0.532948
# 27     sub_1    7    TASK1T0                    Reposo  0.594617  0.533116  0.554366  0.405383  0.466884  0.445634
# 28     sub_1    7    TASK1T1       Mano_Izquierda_Real  0.521672  0.502105  0.532874  0.478328  0.497895  0.467126
# 29     sub_1    7    TASK1T2         Mano_Derecha_Real  0.511127  0.509392  0.538060  0.488873  0.490608  0.461940
# 30     sub_1    8    TASK2T0                    Reposo  0.528228  0.526696  0.561041  0.471772  0.473304  0.438959
# 31     sub_1    8    TASK2T1  Mano_Izquierda_Imaginado  0.558578  0.559618  0.578507  0.441422  0.440382  0.421493
# 32     sub_1    8    TASK2T2    Mano_Derecha_Imaginado  0.411679  0.429459  0.436568  0.588321  0.570541  0.563432
# 33     sub_1    9    TASK3T0                    Reposo  0.499631  0.478654  0.564424  0.500369  0.521346  0.435576
# 34     sub_1    9    TASK3T1          Ambos_Punos_Real  0.537563  0.538817  0.548825  0.462437  0.461183  0.451175
# 35     sub_1    9    TASK3T2           Ambos_Pies_Real  0.469986  0.458969  0.495378  0.530014  0.541031  0.504622
# 36    sub_10   10    TASK4T0                    Reposo  0.511919  0.494904  0.515771  0.488081  0.505096  0.484229
# 37    sub_10   10    TASK4T1     Ambos_Punos_Imaginado  0.412129  0.426375  0.367407  0.587871  0.573625  0.632593
# 38    sub_10   10    TASK4T2      Ambos_Pies_Imaginado  0.450012  0.402908  0.416564  0.549988  0.597092  0.583436
# 39    sub_10   11    TASK1T0                    Reposo  0.534839  0.507810  0.487970  0.465161  0.492190  0.512030
# 40    sub_10   11    TASK1T1       Mano_Izquierda_Real  0.484343  0.459292  0.480976  0.515657  0.540708  0.519024
# 41    sub_10   11    TASK1T2         Mano_Derecha_Real  0.490122  0.374838  0.413654  0.509878  0.625162  0.586346
# 42    sub_10   12    TASK2T0                    Reposo  0.528593  0.477171  0.483596  0.471407  0.522829  0.516404
# 43    sub_10   12    TASK2T1  Mano_Izquierda_Imaginado  0.507391  0.462404  0.465237  0.492609  0.537596  0.534763
# 44    sub_10   12    TASK2T2    Mano_Derecha_Imaginado  0.520899  0.583579  0.531577  0.479101  0.416421  0.468423
# 45    sub_10   13    TASK3T0                    Reposo  0.539573  0.480289  0.584039  0.460427  0.519711  0.415961
# 46    sub_10   13    TASK3T1          Ambos_Punos_Real  0.489224  0.425499  0.470315  0.510776  0.574501  0.529685
# 47    sub_10   13    TASK3T2           Ambos_Pies_Real  0.348338  0.364389  0.338449  0.651662  0.635611  0.661551
# 48    sub_10   14    TASK4T0                    Reposo  0.457590  0.391958  0.430980  0.542410  0.608042  0.569020
# 49    sub_10   14    TASK4T1     Ambos_Punos_Imaginado  0.454687  0.397805  0.392698  0.545313  0.602195  0.607302
# 50    sub_10   14    TASK4T2      Ambos_Pies_Imaginado  0.573576  0.442217  0.511674  0.426424  0.557783  0.488326
# 51    sub_10    3    TASK1T0                    Reposo  0.567700  0.493014  0.532478  0.432300  0.506986  0.467522
# 52    sub_10    3    TASK1T1       Mano_Izquierda_Real  0.564244  0.544942  0.499492  0.435756  0.455058  0.500508
# 53    sub_10    3    TASK1T2         Mano_Derecha_Real  0.521013  0.418509  0.484082  0.478987  0.581491  0.515918
# 54    sub_10    4    TASK2T0                    Reposo  0.531558  0.461169  0.452496  0.468442  0.538831  0.547504
# 55    sub_10    4    TASK2T1  Mano_Izquierda_Imaginado  0.537739  0.538880  0.518495  0.462261  0.461120  0.481505
# 56    sub_10    4    TASK2T2    Mano_Derecha_Imaginado  0.509964  0.445472  0.479215  0.490036  0.554528  0.520785
# 57    sub_10    5    TASK3T0                    Reposo  0.547057  0.517881  0.578266  0.452943  0.482119  0.421734
# 58    sub_10    5    TASK3T1          Ambos_Punos_Real  0.504904  0.468868  0.499710  0.495096  0.531132  0.500290
# 59    sub_10    5    TASK3T2           Ambos_Pies_Real  0.386925  0.413478  0.448971  0.613075  0.586522  0.551029
# 60    sub_10    6    TASK4T0                    Reposo  0.557761  0.493902  0.495688  0.442239  0.506098  0.504312
# 61    sub_10    6    TASK4T1     Ambos_Punos_Imaginado  0.399263  0.445292  0.396963  0.600737  0.554708  0.603037
# 62    sub_10    6    TASK4T2      Ambos_Pies_Imaginado  0.485840  0.425195  0.470876  0.514160  0.574805  0.529124
# 63    sub_10    7    TASK1T0                    Reposo  0.443418  0.406112  0.396714  0.556582  0.593888  0.603286
# 64    sub_10    7    TASK1T1       Mano_Izquierda_Real  0.454655  0.368221  0.373910  0.545345  0.631779  0.626090
# 65    sub_10    7    TASK1T2         Mano_Derecha_Real  0.547338  0.431491  0.441290  0.452662  0.568509  0.558710
# 66    sub_10    8    TASK2T0                    Reposo  0.562094  0.470913  0.506550  0.437906  0.529087  0.493450
# 67    sub_10    8    TASK2T1  Mano_Izquierda_Imaginado  0.458927  0.416352  0.424226  0.541073  0.583648  0.575774
# 68    sub_10    8    TASK2T2    Mano_Derecha_Imaginado  0.468363  0.432754  0.436144  0.531637  0.567246  0.563856
# 69    sub_10    9    TASK3T0                    Reposo  0.434281  0.480163  0.512035  0.565719  0.519837  0.487965
# 70    sub_10    9    TASK3T1          Ambos_Punos_Real  0.445954  0.434647  0.433719  0.554046  0.565353  0.566281
# 71    sub_10    9    TASK3T2           Ambos_Pies_Real  0.441586  0.305766  0.417068  0.558414  0.694234  0.582932
# 72    sub_11   10    TASK4T0                    Reposo  0.577373  0.571040  0.544751  0.422627  0.428960  0.455249
# 73    sub_11   10    TASK4T1     Ambos_Punos_Imaginado  0.613281  0.656010  0.613484  0.386719  0.343990  0.386516
# 74    sub_11   10    TASK4T2      Ambos_Pies_Imaginado  0.673874  0.637664  0.598073  0.326126  0.362336  0.401927
# 75    sub_11   11    TASK1T0                    Reposo  0.733158  0.676481  0.653934  0.266842  0.323519  0.346066
# 76    sub_11   11    TASK1T1       Mano_Izquierda_Real  0.688155  0.653150  0.620970  0.311845  0.346850  0.379030
# 77    sub_11   11    TASK1T2         Mano_Derecha_Real  0.738727  0.693555  0.699828  0.261273  0.306445  0.300172
# 78    sub_11   12    TASK2T0                    Reposo  0.667052  0.630119  0.617257  0.332948  0.369881  0.382743
# 79    sub_11   12    TASK2T1  Mano_Izquierda_Imaginado  0.642761  0.628905  0.608873  0.357239  0.371095  0.391127
# 80    sub_11   12    TASK2T2    Mano_Derecha_Imaginado  0.671452  0.636389  0.633307  0.328548  0.363611  0.366693
# 81    sub_11   13    TASK3T0                    Reposo  0.698556  0.668323  0.658206  0.301444  0.331677  0.341794
# 82    sub_11   13    TASK3T1          Ambos_Punos_Real  0.651533  0.651419  0.629140  0.348467  0.348581  0.370860
# 83    sub_11   13    TASK3T2           Ambos_Pies_Real  0.622030  0.586008  0.583842  0.377970  0.413992  0.416158
# 84    sub_11   14    TASK4T0                    Reposo  0.613405  0.649843  0.615710  0.386595  0.350157  0.384290
# 85    sub_11   14    TASK4T1     Ambos_Punos_Imaginado  0.654650  0.576619  0.603381  0.345350  0.423381  0.396619
# 86    sub_11   14    TASK4T2      Ambos_Pies_Imaginado  0.624263  0.581572  0.567223  0.375737  0.418428  0.432777
# 87    sub_11    3    TASK1T0                    Reposo  0.559619  0.560441  0.552557  0.440381  0.439559  0.447443
# 88    sub_11    3    TASK1T1       Mano_Izquierda_Real  0.559431  0.571497  0.547886  0.440569  0.428503  0.452114
# 89    sub_11    3    TASK1T2         Mano_Derecha_Real  0.526472  0.509534  0.499714  0.473528  0.490466  0.500286
# 90    sub_11    4    TASK2T0                    Reposo  0.575190  0.548239  0.528861  0.424810  0.451761  0.471139
# 91    sub_11    4    TASK2T1  Mano_Izquierda_Imaginado  0.544529  0.548925  0.503957  0.455471  0.451075  0.496043
# 92    sub_11    4    TASK2T2    Mano_Derecha_Imaginado  0.545323  0.521106  0.501480  0.454677  0.478894  0.498520
# 93    sub_11    5    TASK3T0                    Reposo  0.568909  0.592920  0.540573  0.431091  0.407080  0.459427
# 94    sub_11    5    TASK3T1          Ambos_Punos_Real  0.522518  0.583999  0.520586  0.477482  0.416001  0.479414
# 95    sub_11    5    TASK3T2           Ambos_Pies_Real  0.506712  0.522409  0.492998  0.493288  0.477591  0.507002
# 96    sub_11    6    TASK4T0                    Reposo  0.578905  0.589655  0.565116  0.421095  0.410345  0.434884
# 97    sub_11    6    TASK4T1     Ambos_Punos_Imaginado  0.570412  0.498244  0.513567  0.429588  0.501756  0.486433
# 98    sub_11    6    TASK4T2      Ambos_Pies_Imaginado  0.501323  0.471925  0.449864  0.498677  0.528075  0.550136
# 99    sub_11    7    TASK1T0                    Reposo  0.655142  0.612177  0.595727  0.344858  0.387823  0.404273
# 100   sub_11    7    TASK1T1       Mano_Izquierda_Real  0.606634  0.625634  0.600705  0.393366  0.374366  0.399295
# 101   sub_11    7    TASK1T2         Mano_Derecha_Real  0.649718  0.577620  0.596074  0.350282  0.422380  0.403926
# 102   sub_11    8    TASK2T0                    Reposo  0.604610  0.565458  0.569139  0.395390  0.434542  0.430861
# 103   sub_11    8    TASK2T1  Mano_Izquierda_Imaginado  0.526946  0.498327  0.477645  0.473054  0.501673  0.522355
# 104   sub_11    8    TASK2T2    Mano_Derecha_Imaginado  0.561837  0.577798  0.542631  0.438163  0.422202  0.457369
# 105   sub_11    9    TASK3T0                    Reposo  0.573907  0.603658  0.556972  0.426093  0.396342  0.443028
# 106   sub_11    9    TASK3T1          Ambos_Punos_Real  0.562462  0.525837  0.549467  0.437538  0.474163  0.450533
# 107   sub_11    9    TASK3T2           Ambos_Pies_Real  0.463557  0.550697  0.504031  0.536443  0.449303  0.495969
# 108   sub_12   10    TASK4T0                    Reposo  0.515392  0.511667  0.485052  0.484608  0.488333  0.514948
# 109   sub_12   10    TASK4T1     Ambos_Punos_Imaginado  0.556433  0.448131  0.456254  0.443567  0.551869  0.543746
# 110   sub_12   10    TASK4T2      Ambos_Pies_Imaginado  0.427015  0.431665  0.412728  0.572985  0.568335  0.587272
# 111   sub_12   11    TASK1T0                    Reposo  0.546347  0.476165  0.473915  0.453653  0.523835  0.526085
# 112   sub_12   11    TASK1T1       Mano_Izquierda_Real  0.468270  0.507494  0.439424  0.531730  0.492506  0.560576
# 113   sub_12   11    TASK1T2         Mano_Derecha_Real  0.506693  0.480097  0.459692  0.493307  0.519903  0.540308
# 114   sub_12   12    TASK2T0                    Reposo  0.504757  0.444642  0.427452  0.495243  0.555358  0.572548
# 115   sub_12   12    TASK2T1  Mano_Izquierda_Imaginado  0.431250  0.390035  0.384956  0.568750  0.609965  0.615044
# 116   sub_12   12    TASK2T2    Mano_Derecha_Imaginado  0.515898  0.407852  0.423209  0.484102  0.592148  0.576791
# 117   sub_12   13    TASK3T0                    Reposo  0.564205  0.492145  0.490270  0.435795  0.507855  0.509730
# 118   sub_12   13    TASK3T1          Ambos_Punos_Real  0.523945  0.419399  0.419072  0.476055  0.580601  0.580928
# 119   sub_12   13    TASK3T2           Ambos_Pies_Real  0.480288  0.415029  0.405853  0.519712  0.584971  0.594147
# 120   sub_12   14    TASK4T0                    Reposo  0.437890  0.416339  0.399806  0.562110  0.583661  0.600194
# 121   sub_12   14    TASK4T1     Ambos_Punos_Imaginado  0.469233  0.460895  0.408220  0.530767  0.539105  0.591780
# 122   sub_12   14    TASK4T2      Ambos_Pies_Imaginado  0.528681  0.489322  0.479122  0.471319  0.510678  0.520878
# 123   sub_12    3    TASK1T0                    Reposo  0.554166  0.489459  0.476069  0.445834  0.510541  0.523931
# 124   sub_12    3    TASK1T1       Mano_Izquierda_Real  0.572662  0.535096  0.492746  0.427338  0.464904  0.507254
# 125   sub_12    3    TASK1T2         Mano_Derecha_Real  0.639362  0.584856  0.538750  0.360638  0.415144  0.461250
# 126   sub_12    4    TASK2T0                    Reposo  0.568426  0.544418  0.519533  0.431574  0.455582  0.480467
# 127   sub_12    4    TASK2T1  Mano_Izquierda_Imaginado  0.548576  0.525985  0.473909  0.451424  0.474015  0.526091
# 128   sub_12    4    TASK2T2    Mano_Derecha_Imaginado  0.556676  0.522169  0.475149  0.443324  0.477831  0.524851
# 129   sub_12    5    TASK3T0                    Reposo  0.563074  0.574576  0.536646  0.436926  0.425424  0.463354
# 130   sub_12    5    TASK3T1          Ambos_Punos_Real  0.565475  0.512192  0.500128  0.434525  0.487808  0.499872
# 131   sub_12    5    TASK3T2           Ambos_Pies_Real  0.529752  0.514205  0.446825  0.470248  0.485795  0.553175
# 132   sub_12    6    TASK4T0                    Reposo  0.547606  0.563728  0.513562  0.452394  0.436272  0.486438
# 133   sub_12    6    TASK4T1     Ambos_Punos_Imaginado  0.495514  0.462043  0.425594  0.504486  0.537957  0.574406
# 134   sub_12    6    TASK4T2      Ambos_Pies_Imaginado  0.486882  0.446780  0.398094  0.513118  0.553220  0.601906
# 135   sub_12    7    TASK1T0                    Reposo  0.592999  0.511771  0.495769  0.407001  0.488229  0.504231
# 136   sub_12    7    TASK1T1       Mano_Izquierda_Real  0.589696  0.526642  0.489581  0.410304  0.473358  0.510419
# 137   sub_12    7    TASK1T2         Mano_Derecha_Real  0.558239  0.419433  0.412026  0.441761  0.580567  0.587974
# 138   sub_12    8    TASK2T0                    Reposo  0.544125  0.485900  0.475678  0.455875  0.514100  0.524322
# 139   sub_12    8    TASK2T1  Mano_Izquierda_Imaginado  0.603434  0.465020  0.477695  0.396566  0.534980  0.522305
# 140   sub_12    8    TASK2T2    Mano_Derecha_Imaginado  0.585700  0.484465  0.485347  0.414300  0.515535  0.514653
# 141   sub_12    9    TASK3T0                    Reposo  0.497064  0.455897  0.490888  0.502936  0.544103  0.509112
# 142   sub_12    9    TASK3T1          Ambos_Punos_Real  0.559682  0.467302  0.455123  0.440318  0.532698  0.544877
# 143   sub_12    9    TASK3T2           Ambos_Pies_Real  0.531553  0.452382  0.443028  0.468447  0.547618  0.556972
# 144   sub_13   10    TASK4T0                    Reposo  0.620794  0.627674  0.598638  0.379206  0.372326  0.401362
# 145   sub_13   10    TASK4T1     Ambos_Punos_Imaginado  0.555659  0.604409  0.559453  0.444341  0.395591  0.440547
# 146   sub_13   10    TASK4T2      Ambos_Pies_Imaginado  0.693454  0.699959  0.608975  0.306546  0.300041  0.391025
# 147   sub_13   11    TASK1T0                    Reposo  0.665872  0.644073  0.543255  0.334128  0.355927  0.456745
# 148   sub_13   11    TASK1T1       Mano_Izquierda_Real  0.683936  0.717657  0.664132  0.316064  0.282343  0.335868
# 149   sub_13   11    TASK1T2         Mano_Derecha_Real  0.641578  0.607443  0.543900  0.358422  0.392557  0.456100
# 150   sub_13   12    TASK2T0                    Reposo  0.515509  0.627343  0.487353  0.484491  0.372657  0.512647
# 151   sub_13   12    TASK2T1  Mano_Izquierda_Imaginado  0.590897  0.638026  0.502457  0.409103  0.361974  0.497543
# 152   sub_13   12    TASK2T2    Mano_Derecha_Imaginado  0.690100  0.732246  0.638669  0.309900  0.267754  0.361331
# 153   sub_13   13    TASK3T0                    Reposo  0.739853  0.675632  0.618581  0.260147  0.324368  0.381419
# 154   sub_13   13    TASK3T1          Ambos_Punos_Real  0.718428  0.610558  0.623811  0.281572  0.389442  0.376189
# 155   sub_13   13    TASK3T2           Ambos_Pies_Real  0.790192  0.718263  0.695139  0.209808  0.281737  0.304861
# 156   sub_13   14    TASK4T0                    Reposo  0.622836  0.596913  0.562182  0.377164  0.403087  0.437818
# 157   sub_13   14    TASK4T1     Ambos_Punos_Imaginado  0.582044  0.496498  0.475567  0.417956  0.503502  0.524433
# 158   sub_13   14    TASK4T2      Ambos_Pies_Imaginado  0.757130  0.737541  0.716264  0.242870  0.262459  0.283736
# 159   sub_13    3    TASK1T0                    Reposo  0.694725  0.634826  0.581618  0.305275  0.365174  0.418382
# 160   sub_13    3    TASK1T1       Mano_Izquierda_Real  0.754645  0.676580  0.705940  0.245355  0.323420  0.294060
# 161   sub_13    3    TASK1T2         Mano_Derecha_Real  0.718248  0.654311  0.683661  0.281752  0.345689  0.316339
# 162   sub_13    4    TASK2T0                    Reposo  0.643547  0.668224  0.634249  0.356453  0.331776  0.365751
# 163   sub_13    4    TASK2T1  Mano_Izquierda_Imaginado  0.705823  0.641492  0.696868  0.294177  0.358508  0.303132
# 164   sub_13    4    TASK2T2    Mano_Derecha_Imaginado  0.588868  0.629014  0.579525  0.411132  0.370986  0.420475
# 165   sub_13    5    TASK3T0                    Reposo  0.783271  0.717123  0.694723  0.216729  0.282877  0.305277
# 166   sub_13    5    TASK3T1          Ambos_Punos_Real  0.792364  0.742719  0.724819  0.207636  0.257281  0.275181
# 167   sub_13    5    TASK3T2           Ambos_Pies_Real  0.807422  0.772668  0.714254  0.192578  0.227332  0.285746
# 168   sub_13    6    TASK4T0                    Reposo  0.650146  0.635845  0.651824  0.349854  0.364155  0.348176
# 169   sub_13    6    TASK4T1     Ambos_Punos_Imaginado  0.653110  0.593370  0.583025  0.346890  0.406630  0.416975
# 170   sub_13    6    TASK4T2      Ambos_Pies_Imaginado  0.689229  0.641120  0.627368  0.310771  0.358880  0.372632
# 171   sub_13    7    TASK1T0                    Reposo  0.586683  0.599373  0.557331  0.413317  0.400627  0.442669
# 172   sub_13    7    TASK1T1       Mano_Izquierda_Real  0.673817  0.727271  0.681477  0.326183  0.272729  0.318523
# 173   sub_13    7    TASK1T2         Mano_Derecha_Real  0.657249  0.709806  0.686724  0.342751  0.290194  0.313276
# 174   sub_13    8    TASK2T0                    Reposo  0.663857  0.673630  0.615585  0.336143  0.326370  0.384415
# 175   sub_13    8    TASK2T1  Mano_Izquierda_Imaginado  0.596894  0.587647  0.510105  0.403106  0.412353  0.489895
# 176   sub_13    8    TASK2T2    Mano_Derecha_Imaginado  0.677591  0.720348  0.643887  0.322409  0.279652  0.356113
# 177   sub_13    9    TASK3T0                    Reposo  0.735505  0.715233  0.652609  0.264495  0.284767  0.347391
# 178   sub_13    9    TASK3T1          Ambos_Punos_Real  0.758110  0.680801  0.693801  0.241890  0.319199  0.306199
# 179   sub_13    9    TASK3T2           Ambos_Pies_Real  0.683508  0.613860  0.570969  0.316492  0.386140  0.429031
# 180   sub_14   10    TASK4T0                    Reposo  0.293466  0.296061  0.298567  0.706534  0.703939  0.701433
# 181   sub_14   10    TASK4T1     Ambos_Punos_Imaginado  0.227538  0.244764  0.220747  0.772462  0.755236  0.779253
# 182   sub_14   10    TASK4T2      Ambos_Pies_Imaginado  0.232570  0.243478  0.198604  0.767430  0.756522  0.801396
# 183   sub_14   11    TASK1T0                    Reposo  0.297828  0.331671  0.272336  0.702172  0.668329  0.727664
# 184   sub_14   11    TASK1T1       Mano_Izquierda_Real  0.347379  0.346064  0.317951  0.652621  0.653936  0.682049
# 185   sub_14   11    TASK1T2         Mano_Derecha_Real  0.284158  0.356197  0.277624  0.715842  0.643803  0.722376
# 186   sub_14   12    TASK2T0                    Reposo  0.264328  0.292737  0.249719  0.735672  0.707263  0.750281
# 187   sub_14   12    TASK2T1  Mano_Izquierda_Imaginado  0.248781  0.255702  0.218117  0.751219  0.744298  0.781883
# 188   sub_14   12    TASK2T2    Mano_Derecha_Imaginado  0.196695  0.236266  0.187730  0.803305  0.763734  0.812270
# 189   sub_14   13    TASK3T0                    Reposo  0.335847  0.363852  0.399031  0.664153  0.636148  0.600969
# 190   sub_14   13    TASK3T1          Ambos_Punos_Real  0.369935  0.345120  0.302527  0.630065  0.654880  0.697473
# 191   sub_14   13    TASK3T2           Ambos_Pies_Real  0.297073  0.313038  0.290455  0.702927  0.686962  0.709545
# 192   sub_14   14    TASK4T0                    Reposo  0.249233  0.250981  0.221327  0.750767  0.749019  0.778673
# 193   sub_14   14    TASK4T1     Ambos_Punos_Imaginado  0.259278  0.280010  0.237978  0.740722  0.719990  0.762022
# 194   sub_14   14    TASK4T2      Ambos_Pies_Imaginado  0.328418  0.362525  0.285908  0.671582  0.637475  0.714092
# 195   sub_14    3    TASK1T0                    Reposo  0.378666  0.378137  0.356070  0.621334  0.621863  0.643930
# 196   sub_14    3    TASK1T1       Mano_Izquierda_Real  0.482272  0.510195  0.417806  0.517728  0.489805  0.582194
# 197   sub_14    3    TASK1T2         Mano_Derecha_Real  0.463329  0.486619  0.442807  0.536671  0.513381  0.557193
# 198   sub_14    4    TASK2T0                    Reposo  0.367184  0.371759  0.332012  0.632816  0.628241  0.667988
# 199   sub_14    4    TASK2T1  Mano_Izquierda_Imaginado  0.398024  0.376090  0.336429  0.601976  0.623910  0.663571
# 200   sub_14    4    TASK2T2    Mano_Derecha_Imaginado  0.307711  0.324315  0.267551  0.692289  0.675685  0.732449
# 201   sub_14    5    TASK3T0                    Reposo  0.426373  0.379546  0.360023  0.573627  0.620454  0.639977
# 202   sub_14    5    TASK3T1          Ambos_Punos_Real  0.391255  0.364067  0.317929  0.608745  0.635933  0.682071
# 203   sub_14    5    TASK3T2           Ambos_Pies_Real  0.399283  0.424007  0.342258  0.600717  0.575993  0.657742
# 204   sub_14    6    TASK4T0                    Reposo  0.336090  0.364216  0.316200  0.663910  0.635784  0.683800
# 205   sub_14    6    TASK4T1     Ambos_Punos_Imaginado  0.292040  0.351204  0.295935  0.707960  0.648796  0.704065
# 206   sub_14    6    TASK4T2      Ambos_Pies_Imaginado  0.374733  0.388734  0.345381  0.625267  0.611266  0.654619
# 207   sub_14    7    TASK1T0                    Reposo  0.353089  0.349770  0.310471  0.646911  0.650230  0.689529
# 208   sub_14    7    TASK1T1       Mano_Izquierda_Real  0.322843  0.337128  0.281882  0.677157  0.662872  0.718118
# 209   sub_14    7    TASK1T2         Mano_Derecha_Real  0.302073  0.357019  0.279905  0.697927  0.642981  0.720095
# 210   sub_14    8    TASK2T0                    Reposo  0.247255  0.262118  0.223827  0.752745  0.737882  0.776173
# 211   sub_14    8    TASK2T1  Mano_Izquierda_Imaginado  0.250976  0.291110  0.235032  0.749024  0.708890  0.764968
# 212   sub_14    8    TASK2T2    Mano_Derecha_Imaginado  0.308593  0.306324  0.250540  0.691407  0.693676  0.749460
# 213   sub_14    9    TASK3T0                    Reposo  0.343939  0.353777  0.376029  0.656061  0.646223  0.623971
# 214   sub_14    9    TASK3T1          Ambos_Punos_Real  0.373432  0.319992  0.299360  0.626568  0.680008  0.700640
# 215   sub_14    9    TASK3T2           Ambos_Pies_Real  0.392848  0.408603  0.358345  0.607152  0.591397  0.641655
# 216   sub_15   10    TASK4T0                    Reposo  0.583579  0.591128  0.594346  0.416421  0.408872  0.405654
# 217   sub_15   10    TASK4T1     Ambos_Punos_Imaginado  0.596939  0.580253  0.604793  0.403061  0.419747  0.395207
# 218   sub_15   10    TASK4T2      Ambos_Pies_Imaginado  0.585490  0.551684  0.591553  0.414510  0.448316  0.408447
# 219   sub_15   11    TASK1T0                    Reposo  0.662235  0.574893  0.632272  0.337765  0.425107  0.367728
# 220   sub_15   11    TASK1T1       Mano_Izquierda_Real  0.649158  0.606130  0.612374  0.350842  0.393870  0.387626
# 221   sub_15   11    TASK1T2         Mano_Derecha_Real  0.645048  0.606613  0.612724  0.354952  0.393387  0.387276
# 222   sub_15   12    TASK2T0                    Reposo  0.683537  0.648075  0.670342  0.316463  0.351925  0.329658
# 223   sub_15   12    TASK2T1  Mano_Izquierda_Imaginado  0.595395  0.582472  0.582477  0.404605  0.417528  0.417523
# 224   sub_15   12    TASK2T2    Mano_Derecha_Imaginado  0.591972  0.559944  0.582345  0.408028  0.440056  0.417655
# 225   sub_15   13    TASK3T0                    Reposo  0.588309  0.560373  0.599076  0.411691  0.439627  0.400924
# 226   sub_15   13    TASK3T1          Ambos_Punos_Real  0.616600  0.597233  0.640529  0.383400  0.402767  0.359471
# 227   sub_15   13    TASK3T2           Ambos_Pies_Real  0.587896  0.574522  0.576967  0.412104  0.425478  0.423033
# 228   sub_15   14    TASK4T0                    Reposo  0.588062  0.544832  0.594811  0.411938  0.455168  0.405189
# 229   sub_15   14    TASK4T1     Ambos_Punos_Imaginado  0.485997  0.521729  0.486879  0.514003  0.478271  0.513121
# 230   sub_15   14    TASK4T2      Ambos_Pies_Imaginado  0.546847  0.567678  0.596679  0.453153  0.432322  0.403321
# 231   sub_15    3    TASK1T0                    Reposo  0.710511  0.697315  0.676459  0.289489  0.302685  0.323541
# 232   sub_15    3    TASK1T1       Mano_Izquierda_Real  0.673149  0.730026  0.669083  0.326851  0.269974  0.330917
# 233   sub_15    3    TASK1T2         Mano_Derecha_Real  0.623778  0.652545  0.594230  0.376222  0.347455  0.405770
# 234   sub_15    4    TASK2T0                    Reposo  0.675757  0.683404  0.634089  0.324243  0.316596  0.365911
# 235   sub_15    4    TASK2T1  Mano_Izquierda_Imaginado  0.635034  0.671906  0.640250  0.364966  0.328094  0.359750
# 236   sub_15    4    TASK2T2    Mano_Derecha_Imaginado  0.657180  0.608074  0.638392  0.342820  0.391926  0.361608
# 237   sub_15    5    TASK3T0                    Reposo  0.661707  0.661744  0.648669  0.338293  0.338256  0.351331
# 238   sub_15    5    TASK3T1          Ambos_Punos_Real  0.592532  0.539047  0.539744  0.407468  0.460953  0.460256
# 239   sub_15    5    TASK3T2           Ambos_Pies_Real  0.595104  0.619249  0.589283  0.404896  0.380751  0.410717
# 240   sub_15    6    TASK4T0                    Reposo  0.643186  0.570667  0.609193  0.356814  0.429333  0.390807
# 241   sub_15    6    TASK4T1     Ambos_Punos_Imaginado  0.584600  0.559773  0.563789  0.415400  0.440227  0.436211
# 242   sub_15    6    TASK4T2      Ambos_Pies_Imaginado  0.581521  0.587515  0.614908  0.418479  0.412485  0.385092
# 243   sub_15    7    TASK1T0                    Reposo  0.702070  0.697782  0.687970  0.297930  0.302218  0.312030
# 244   sub_15    7    TASK1T1       Mano_Izquierda_Real  0.604596  0.649932  0.598812  0.395404  0.350068  0.401188
# 245   sub_15    7    TASK1T2         Mano_Derecha_Real  0.639973  0.581710  0.622302  0.360027  0.418290  0.377698
# 246   sub_15    8    TASK2T0                    Reposo  0.616488  0.603628  0.601580  0.383512  0.396372  0.398420
# 247   sub_15    8    TASK2T1  Mano_Izquierda_Imaginado  0.495386  0.498128  0.452480  0.504614  0.501872  0.547520
# 248   sub_15    8    TASK2T2    Mano_Derecha_Imaginado  0.659365  0.617922  0.659893  0.340635  0.382078  0.340107
# 249   sub_15    9    TASK3T0                    Reposo  0.644610  0.555925  0.601254  0.355390  0.444075  0.398746
# 250   sub_15    9    TASK3T1          Ambos_Punos_Real  0.647352  0.524806  0.584912  0.352648  0.475194  0.415088
# 251   sub_15    9    TASK3T2           Ambos_Pies_Real  0.632651  0.546420  0.614009  0.367349  0.453580  0.385991
# 252   sub_16   10    TASK4T0                    Reposo  0.473912  0.495950  0.461059  0.526088  0.504050  0.538941
# 253   sub_16   10    TASK4T1     Ambos_Punos_Imaginado  0.473958  0.513258  0.459175  0.526042  0.486742  0.540825
# 254   sub_16   10    TASK4T2      Ambos_Pies_Imaginado  0.435413  0.412278  0.378970  0.564587  0.587722  0.621030
# 255   sub_16   11    TASK1T0                    Reposo  0.558648  0.552913  0.534733  0.441352  0.447087  0.465267
# 256   sub_16   11    TASK1T1       Mano_Izquierda_Real  0.440295  0.407953  0.415314  0.559705  0.592047  0.584686
# 257   sub_16   11    TASK1T2         Mano_Derecha_Real  0.438210  0.436322  0.404406  0.561790  0.563678  0.595594
# 258   sub_16   12    TASK2T0                    Reposo  0.562195  0.555873  0.552581  0.437805  0.444127  0.447419
# 259   sub_16   12    TASK2T1  Mano_Izquierda_Imaginado  0.382458  0.376134  0.343451  0.617542  0.623866  0.656549
# 260   sub_16   12    TASK2T2    Mano_Derecha_Imaginado  0.483276  0.502902  0.478985  0.516724  0.497098  0.521015
# 261   sub_16   13    TASK3T0                    Reposo  0.519446  0.489686  0.478784  0.480554  0.510314  0.521216
# 262   sub_16   13    TASK3T1          Ambos_Punos_Real  0.469109  0.427604  0.427303  0.530891  0.572396  0.572697
# 263   sub_16   13    TASK3T2           Ambos_Pies_Real  0.421086  0.466092  0.396117  0.578914  0.533908  0.603883
# 264   sub_16   14    TASK4T0                    Reposo  0.453788  0.409121  0.397765  0.546212  0.590879  0.602235
# 265   sub_16   14    TASK4T1     Ambos_Punos_Imaginado  0.517237  0.545752  0.503977  0.482763  0.454248  0.496023
# 266   sub_16   14    TASK4T2      Ambos_Pies_Imaginado  0.566470  0.590535  0.540242  0.433530  0.409465  0.459758
# 267   sub_16    3    TASK1T0                    Reposo  0.555535  0.592916  0.546855  0.444465  0.407084  0.453145
# 268   sub_16    3    TASK1T1       Mano_Izquierda_Real  0.453840  0.461643  0.436176  0.546160  0.538357  0.563824
# 269   sub_16    3    TASK1T2         Mano_Derecha_Real  0.540300  0.557836  0.542139  0.459700  0.442164  0.457861
# 270   sub_16    4    TASK2T0                    Reposo  0.478825  0.472768  0.461033  0.521175  0.527232  0.538967
# 271   sub_16    4    TASK2T1  Mano_Izquierda_Imaginado  0.448576  0.482189  0.447045  0.551424  0.517811  0.552955
# 272   sub_16    4    TASK2T2    Mano_Derecha_Imaginado  0.510616  0.535926  0.464439  0.489384  0.464074  0.535561
# 273   sub_16    5    TASK3T0                    Reposo  0.499244  0.512572  0.467894  0.500756  0.487428  0.532106
# 274   sub_16    5    TASK3T1          Ambos_Punos_Real  0.496272  0.483558  0.448131  0.503728  0.516442  0.551869
# 275   sub_16    5    TASK3T2           Ambos_Pies_Real  0.422357  0.445430  0.393062  0.577643  0.554570  0.606938
# 276   sub_16    6    TASK4T0                    Reposo  0.463587  0.469337  0.425221  0.536413  0.530663  0.574779
# 277   sub_16    6    TASK4T1     Ambos_Punos_Imaginado  0.460289  0.449968  0.427691  0.539711  0.550032  0.572309
# 278   sub_16    6    TASK4T2      Ambos_Pies_Imaginado  0.411575  0.461382  0.400905  0.588425  0.538618  0.599095
# 279   sub_16    7    TASK1T0                    Reposo  0.510830  0.542357  0.494363  0.489170  0.457643  0.505637
# 280   sub_16    7    TASK1T1       Mano_Izquierda_Real  0.530548  0.559714  0.525386  0.469452  0.440286  0.474614
# 281   sub_16    7    TASK1T2         Mano_Derecha_Real  0.434804  0.463979  0.425849  0.565196  0.536021  0.574151
# 282   sub_16    8    TASK2T0                    Reposo  0.410606  0.433945  0.405473  0.589394  0.566055  0.594527
# 283   sub_16    8    TASK2T1  Mano_Izquierda_Imaginado  0.380806  0.422765  0.382264  0.619194  0.577235  0.617736
# 284   sub_16    8    TASK2T2    Mano_Derecha_Imaginado  0.481382  0.436481  0.404677  0.518618  0.563519  0.595323
# 285   sub_16    9    TASK3T0                    Reposo  0.463625  0.506862  0.476276  0.536375  0.493138  0.523724
# 286   sub_16    9    TASK3T1          Ambos_Punos_Real  0.408832  0.438228  0.392703  0.591168  0.561772  0.607297
# 287   sub_16    9    TASK3T2           Ambos_Pies_Real  0.435896  0.409594  0.382177  0.564104  0.590406  0.617823
# 288   sub_17   10    TASK4T0                    Reposo  0.696499  0.590096  0.480508  0.303501  0.409904  0.519492
# 289   sub_17   10    TASK4T1     Ambos_Punos_Imaginado  0.705546  0.625881  0.498353  0.294454  0.374119  0.501647
# 290   sub_17   10    TASK4T2      Ambos_Pies_Imaginado  0.710015  0.584929  0.500683  0.289985  0.415071  0.499317
# 291   sub_17   11    TASK1T0                    Reposo  0.556658  0.629207  0.429543  0.443342  0.370793  0.570457
# 292   sub_17   11    TASK1T1       Mano_Izquierda_Real  0.491358  0.596366  0.372990  0.508642  0.403634  0.627010
# 293   sub_17   11    TASK1T2         Mano_Derecha_Real  0.613741  0.651160  0.460362  0.386259  0.348840  0.539638
# 294   sub_17   12    TASK2T0                    Reposo  0.633419  0.589219  0.391765  0.366581  0.410781  0.608235
# 295   sub_17   12    TASK2T1  Mano_Izquierda_Imaginado  0.738688  0.714229  0.560315  0.261312  0.285771  0.439685
# 296   sub_17   12    TASK2T2    Mano_Derecha_Imaginado  0.659401  0.690581  0.436653  0.340599  0.309419  0.563347
# 297   sub_17   13    TASK3T0                    Reposo  0.648828  0.643448  0.543063  0.351172  0.356552  0.456937
# 298   sub_17   13    TASK3T1          Ambos_Punos_Real  0.627433  0.586891  0.447205  0.372567  0.413109  0.552795
# 299   sub_17   13    TASK3T2           Ambos_Pies_Real  0.651970  0.628582  0.450466  0.348030  0.371418  0.549534
# 300   sub_17   14    TASK4T0                    Reposo  0.494216  0.480024  0.343929  0.505784  0.519976  0.656071
# 301   sub_17   14    TASK4T1     Ambos_Punos_Imaginado  0.603673  0.657342  0.451148  0.396327  0.342658  0.548852
# 302   sub_17   14    TASK4T2      Ambos_Pies_Imaginado  0.646589  0.645458  0.539973  0.353411  0.354542  0.460027
# 303   sub_17    3    TASK1T0                    Reposo  0.694122  0.635219  0.574944  0.305878  0.364781  0.425056
# 304   sub_17    3    TASK1T1       Mano_Izquierda_Real  0.734945  0.662639  0.596413  0.265055  0.337361  0.403587
# 305   sub_17    3    TASK1T2         Mano_Derecha_Real  0.702955  0.644353  0.581056  0.297045  0.355647  0.418944
# 306   sub_17    4    TASK2T0                    Reposo  0.721708  0.614129  0.571716  0.278292  0.385871  0.428284
# 307   sub_17    4    TASK2T1  Mano_Izquierda_Imaginado  0.756730  0.680850  0.650077  0.243270  0.319150  0.349923
# 308   sub_17    4    TASK2T2    Mano_Derecha_Imaginado  0.707974  0.582489  0.523305  0.292026  0.417511  0.476695
# 309   sub_17    5    TASK3T0                    Reposo  0.712646  0.672188  0.577855  0.287354  0.327812  0.422145
# 310   sub_17    5    TASK3T1          Ambos_Punos_Real  0.659848  0.654548  0.581614  0.340152  0.345452  0.418386
# 311   sub_17    5    TASK3T2           Ambos_Pies_Real  0.485676  0.438218  0.400914  0.514324  0.561782  0.599086
# 312   sub_17    6    TASK4T0                    Reposo  0.671528  0.588997  0.542621  0.328472  0.411003  0.457379
# 313   sub_17    6    TASK4T1     Ambos_Punos_Imaginado  0.701224  0.573108  0.540664  0.298776  0.426892  0.459336
# 314   sub_17    6    TASK4T2      Ambos_Pies_Imaginado  0.691839  0.542941  0.526031  0.308161  0.457059  0.473969
# 315   sub_17    7    TASK1T0                    Reposo  0.595203  0.594598  0.474384  0.404797  0.405402  0.525616
# 316   sub_17    7    TASK1T1       Mano_Izquierda_Real  0.636320  0.655934  0.561215  0.363680  0.344066  0.438785
# 317   sub_17    7    TASK1T2         Mano_Derecha_Real  0.560939  0.490262  0.466365  0.439061  0.509738  0.533635
# 318   sub_17    8    TASK2T0                    Reposo  0.635974  0.552143  0.446460  0.364026  0.447857  0.553540
# 319   sub_17    8    TASK2T1  Mano_Izquierda_Imaginado  0.683807  0.632715  0.496180  0.316193  0.367285  0.503820
# 320   sub_17    8    TASK2T2    Mano_Derecha_Imaginado  0.653041  0.614894  0.490569  0.346959  0.385106  0.509431
# 321   sub_17    9    TASK3T0                    Reposo  0.694604  0.602892  0.501155  0.305396  0.397108  0.498845
# 322   sub_17    9    TASK3T1          Ambos_Punos_Real  0.799633  0.706759  0.634452  0.200367  0.293241  0.365548
# 323   sub_17    9    TASK3T2           Ambos_Pies_Real  0.608095  0.527559  0.436034  0.391905  0.472441  0.563966
# 324   sub_18   10    TASK4T0                    Reposo  0.650033  0.710162  0.656725  0.349967  0.289838  0.343275
# 325   sub_18   10    TASK4T1     Ambos_Punos_Imaginado  0.708421  0.753497  0.706927  0.291579  0.246503  0.293073
# 326   sub_18   10    TASK4T2      Ambos_Pies_Imaginado  0.677846  0.680610  0.654967  0.322154  0.319390  0.345033
# 327   sub_18   11    TASK1T0                    Reposo  0.689535  0.680822  0.659735  0.310465  0.319178  0.340265
# 328   sub_18   11    TASK1T1       Mano_Izquierda_Real  0.641690  0.670688  0.610785  0.358310  0.329312  0.389215
# 329   sub_18   11    TASK1T2         Mano_Derecha_Real  0.695299  0.727655  0.688216  0.304701  0.272345  0.311784
# 330   sub_18   12    TASK2T0                    Reposo  0.683219  0.705666  0.669440  0.316781  0.294334  0.330560
# 331   sub_18   12    TASK2T1  Mano_Izquierda_Imaginado  0.646387  0.655199  0.624646  0.353613  0.344801  0.375354
# 332   sub_18   12    TASK2T2    Mano_Derecha_Imaginado  0.676993  0.711570  0.652520  0.323007  0.288430  0.347480
# 333   sub_18   13    TASK3T0                    Reposo  0.493100  0.525031  0.477136  0.506900  0.474969  0.522864
# 334   sub_18   13    TASK3T1          Ambos_Punos_Real  0.614478  0.630857  0.577902  0.385522  0.369143  0.422098
# 335   sub_18   13    TASK3T2           Ambos_Pies_Real  0.663730  0.679792  0.634201  0.336270  0.320208  0.365799
# 336   sub_18   14    TASK4T0                    Reposo  0.616005  0.651434  0.603680  0.383995  0.348566  0.396320
# 337   sub_18   14    TASK4T1     Ambos_Punos_Imaginado  0.707362  0.719282  0.676308  0.292638  0.280718  0.323692
# 338   sub_18   14    TASK4T2      Ambos_Pies_Imaginado  0.663401  0.727484  0.670693  0.336599  0.272516  0.329307
# 339   sub_18    3    TASK1T0                    Reposo  0.584209  0.581305  0.563985  0.415791  0.418695  0.436015
# 340   sub_18    3    TASK1T1       Mano_Izquierda_Real  0.589316  0.602434  0.564832  0.410684  0.397566  0.435168
# 341   sub_18    3    TASK1T2         Mano_Derecha_Real  0.540907  0.518200  0.518665  0.459093  0.481800  0.481335
# 342   sub_18    4    TASK2T0                    Reposo  0.578291  0.571295  0.537391  0.421709  0.428705  0.462609
# 343   sub_18    4    TASK2T1  Mano_Izquierda_Imaginado  0.602524  0.652423  0.593915  0.397476  0.347577  0.406085
# 344   sub_18    4    TASK2T2    Mano_Derecha_Imaginado  0.626098  0.620332  0.602206  0.373902  0.379668  0.397794
# 345   sub_18    5    TASK3T0                    Reposo  0.653925  0.671711  0.638208  0.346075  0.328289  0.361792
# 346   sub_18    5    TASK3T1          Ambos_Punos_Real  0.678542  0.666921  0.628184  0.321458  0.333079  0.371816
# 347   sub_18    5    TASK3T2           Ambos_Pies_Real  0.606370  0.610521  0.581107  0.393630  0.389479  0.418893
# 348   sub_18    6    TASK4T0                    Reposo  0.662583  0.668053  0.654987  0.337417  0.331947  0.345013
# 349   sub_18    6    TASK4T1     Ambos_Punos_Imaginado  0.725590  0.693759  0.681508  0.274410  0.306241  0.318492
# 350   sub_18    6    TASK4T2      Ambos_Pies_Imaginado  0.682887  0.685277  0.647917  0.317113  0.314723  0.352083
# 351   sub_18    7    TASK1T0                    Reposo  0.624517  0.645432  0.616368  0.375483  0.354568  0.383632
# 352   sub_18    7    TASK1T1       Mano_Izquierda_Real  0.635359  0.659395  0.622709  0.364641  0.340605  0.377291
# 353   sub_18    7    TASK1T2         Mano_Derecha_Real  0.679771  0.695083  0.671051  0.320229  0.304917  0.328949
# 354   sub_18    8    TASK2T0                    Reposo  0.640909  0.679060  0.633155  0.359091  0.320940  0.366845
# 355   sub_18    8    TASK2T1  Mano_Izquierda_Imaginado  0.725304  0.734400  0.717447  0.274696  0.265600  0.282553
# 356   sub_18    8    TASK2T2    Mano_Derecha_Imaginado  0.636900  0.604769  0.589580  0.363100  0.395231  0.410420
# 357   sub_18    9    TASK3T0                    Reposo  0.668906  0.714783  0.660941  0.331094  0.285217  0.339059
# 358   sub_18    9    TASK3T1          Ambos_Punos_Real  0.607591  0.628762  0.559816  0.392409  0.371238  0.440184
# 359   sub_18    9    TASK3T2           Ambos_Pies_Real  0.642415  0.719075  0.650673  0.357585  0.280925  0.349327
# 360   sub_19   10    TASK4T0                    Reposo  0.596552  0.623817  0.594128  0.403448  0.376183  0.405872
# 361   sub_19   10    TASK4T1     Ambos_Punos_Imaginado  0.561553  0.625668  0.571606  0.438447  0.374332  0.428394
# 362   sub_19   10    TASK4T2      Ambos_Pies_Imaginado  0.549916  0.612392  0.589744  0.450084  0.387608  0.410256
# 363   sub_19   11    TASK1T0                    Reposo  0.564464  0.642349  0.570915  0.435536  0.357651  0.429085
# 364   sub_19   11    TASK1T1       Mano_Izquierda_Real  0.630834  0.642832  0.634375  0.369166  0.357168  0.365625
# 365   sub_19   11    TASK1T2         Mano_Derecha_Real  0.556067  0.662559  0.588206  0.443933  0.337441  0.411794
# 366   sub_19   12    TASK2T0                    Reposo  0.577412  0.629674  0.572803  0.422588  0.370326  0.427197
# 367   sub_19   12    TASK2T1  Mano_Izquierda_Imaginado  0.479765  0.563676  0.518419  0.520235  0.436324  0.481581
# 368   sub_19   12    TASK2T2    Mano_Derecha_Imaginado  0.460498  0.561688  0.494185  0.539502  0.438312  0.505815
# 369   sub_19   13    TASK3T0                    Reposo  0.606825  0.661550  0.624829  0.393175  0.338450  0.375171
# 370   sub_19   13    TASK3T1          Ambos_Punos_Real  0.508352  0.570723  0.533128  0.491648  0.429277  0.466872
# 371   sub_19   13    TASK3T2           Ambos_Pies_Real  0.565632  0.646473  0.554807  0.434368  0.353527  0.445193
# 372   sub_19   14    TASK4T0                    Reposo  0.570055  0.657703  0.607497  0.429945  0.342297  0.392503
# 373   sub_19   14    TASK4T1     Ambos_Punos_Imaginado  0.583628  0.648412  0.608379  0.416372  0.351588  0.391621
# 374   sub_19   14    TASK4T2      Ambos_Pies_Imaginado  0.563449  0.680907  0.591508  0.436551  0.319093  0.408492
# 375   sub_19    3    TASK1T0                    Reposo  0.621928  0.643204  0.630219  0.378072  0.356796  0.369781
# 376   sub_19    3    TASK1T1       Mano_Izquierda_Real  0.628351  0.610464  0.599223  0.371649  0.389536  0.400777
# 377   sub_19    3    TASK1T2         Mano_Derecha_Real  0.563481  0.641951  0.598900  0.436519  0.358049  0.401100
# 378   sub_19    4    TASK2T0                    Reposo  0.576778  0.632294  0.588096  0.423222  0.367706  0.411904
# 379   sub_19    4    TASK2T1  Mano_Izquierda_Imaginado  0.539982  0.651113  0.603211  0.460018  0.348887  0.396789
# 380   sub_19    4    TASK2T2    Mano_Derecha_Imaginado  0.551930  0.608649  0.588659  0.448070  0.391351  0.411341
# 381   sub_19    5    TASK3T0                    Reposo  0.677541  0.695192  0.662033  0.322459  0.304808  0.337967
# 382   sub_19    5    TASK3T1          Ambos_Punos_Real  0.616897  0.703232  0.673751  0.383103  0.296768  0.326249
# 383   sub_19    5    TASK3T2           Ambos_Pies_Real  0.608908  0.662454  0.595365  0.391092  0.337546  0.404635
# 384   sub_19    6    TASK4T0                    Reposo  0.551268  0.626655  0.605228  0.448732  0.373345  0.394772
# 385   sub_19    6    TASK4T1     Ambos_Punos_Imaginado  0.645486  0.680773  0.666337  0.354514  0.319227  0.333663
# 386   sub_19    6    TASK4T2      Ambos_Pies_Imaginado  0.547127  0.692869  0.592346  0.452873  0.307131  0.407654
# 387   sub_19    7    TASK1T0                    Reposo  0.589700  0.636899  0.612137  0.410300  0.363101  0.387863
# 388   sub_19    7    TASK1T1       Mano_Izquierda_Real  0.597063  0.679509  0.642980  0.402937  0.320491  0.357020
# 389   sub_19    7    TASK1T2         Mano_Derecha_Real  0.498571  0.621106  0.543530  0.501429  0.378894  0.456470
# 390   sub_19    8    TASK2T0                    Reposo  0.583418  0.600874  0.581705  0.416582  0.399126  0.418295
# 391   sub_19    8    TASK2T1  Mano_Izquierda_Imaginado  0.542866  0.603408  0.533344  0.457134  0.396592  0.466656
# 392   sub_19    8    TASK2T2    Mano_Derecha_Imaginado  0.573865  0.558531  0.543898  0.426135  0.441469  0.456102
# 393   sub_19    9    TASK3T0                    Reposo  0.652264  0.718380  0.682595  0.347736  0.281620  0.317405
# 394   sub_19    9    TASK3T1          Ambos_Punos_Real  0.638046  0.708951  0.659168  0.361954  0.291049  0.340832
# 395   sub_19    9    TASK3T2           Ambos_Pies_Real  0.582297  0.636199  0.573188  0.417703  0.363801  0.426812
# 396    sub_2   10    TASK4T0                    Reposo  0.507143  0.574184  0.597225  0.492857  0.425816  0.402775
# 397    sub_2   10    TASK4T1     Ambos_Punos_Imaginado  0.672568  0.721444  0.721912  0.327432  0.278556  0.278088
# 398    sub_2   10    TASK4T2      Ambos_Pies_Imaginado  0.589788  0.612375  0.640173  0.410212  0.387625  0.359827
# 399    sub_2   11    TASK1T0                    Reposo  0.763324  0.636518  0.683481  0.236676  0.363482  0.316519
# 400    sub_2   11    TASK1T1       Mano_Izquierda_Real  0.557227  0.583317  0.697946  0.442773  0.416683  0.302054
# 401    sub_2   11    TASK1T2         Mano_Derecha_Real  0.579502  0.531582  0.633820  0.420498  0.468418  0.366180
# 402    sub_2   12    TASK2T0                    Reposo  0.674579  0.602209  0.720570  0.325421  0.397791  0.279430
# 403    sub_2   12    TASK2T1  Mano_Izquierda_Imaginado  0.486508  0.538787  0.611963  0.513492  0.461213  0.388037
# 404    sub_2   12    TASK2T2    Mano_Derecha_Imaginado  0.636661  0.546867  0.585892  0.363339  0.453133  0.414108
# 405    sub_2   13    TASK3T0                    Reposo  0.704327  0.784216  0.745510  0.295673  0.215784  0.254490
# 406    sub_2   13    TASK3T1          Ambos_Punos_Real  0.692463  0.596562  0.671524  0.307537  0.403438  0.328476
# 407    sub_2   13    TASK3T2           Ambos_Pies_Real  0.432070  0.434392  0.475914  0.567930  0.565608  0.524086
# 408    sub_2   14    TASK4T0                    Reposo  0.522133  0.530732  0.626245  0.477867  0.469268  0.373755
# 409    sub_2   14    TASK4T1     Ambos_Punos_Imaginado  0.466759  0.515124  0.582540  0.533241  0.484876  0.417460
# ...
# 581    sub_6   11    TASK1T2         Mano_Derecha_Real  0.830298  0.844145  0.794382  0.169702  0.155855  0.205618
# 582    sub_6   12    TASK2T0                    Reposo  0.825022  0.838705  0.804697  0.174978  0.161295  0.195303
# 583    sub_6   12    TASK2T1  Mano_Izquierda_Imaginado  0.766765  0.787338  0.774052  0.233235  0.212662  0.225948
# 584    sub_6   12    TASK2T2    Mano_Derecha_Imaginado  0.791376  0.789644  0.749910  0.208624  0.210356  0.250090
# 585    sub_6   13    TASK3T0                    Reposo  0.743951  0.733747  0.747576  0.256049  0.266253  0.252424
# 586    sub_6   13    TASK3T1          Ambos_Punos_Real  0.773403  0.757852  0.728261  0.226597  0.242148  0.271739
# 587    sub_6   13    TASK3T2           Ambos_Pies_Real  0.736351  0.682404  0.714743  0.263649  0.317596  0.285257
# 588    sub_6   14    TASK4T0                    Reposo  0.771247  0.753623  0.753837  0.228753  0.246377  0.246163
# 589    sub_6   14    TASK4T1     Ambos_Punos_Imaginado  0.757657  0.681433  0.696994  0.242343  0.318567  0.303006
# 590    sub_6   14    TASK4T2      Ambos_Pies_Imaginado  0.751650  0.715159  0.693913  0.248350  0.284841  0.306087
# 591    sub_6    3    TASK1T0                    Reposo  0.741477  0.734786  0.722971  0.258523  0.265214  0.277029
# 592    sub_6    3    TASK1T1       Mano_Izquierda_Real  0.671590  0.656269  0.610736  0.328410  0.343731  0.389264
# 593    sub_6    3    TASK1T2         Mano_Derecha_Real  0.676572  0.703922  0.685354  0.323428  0.296078  0.314646
# 594    sub_6    4    TASK2T0                    Reposo  0.715786  0.745259  0.686814  0.284214  0.254741  0.313186
# 595    sub_6    4    TASK2T1  Mano_Izquierda_Imaginado  0.665674  0.635665  0.588710  0.334326  0.364335  0.411290
# 596    sub_6    4    TASK2T2    Mano_Derecha_Imaginado  0.682912  0.717701  0.669515  0.317088  0.282299  0.330485
# 597    sub_6    5    TASK3T0                    Reposo  0.757168  0.756419  0.743624  0.242832  0.243581  0.256376
# 598    sub_6    5    TASK3T1          Ambos_Punos_Real  0.747617  0.773419  0.751438  0.252383  0.226581  0.248562
# 599    sub_6    5    TASK3T2           Ambos_Pies_Real  0.730179  0.747268  0.675078  0.269821  0.252732  0.324922
# 600    sub_6    6    TASK4T0                    Reposo  0.805561  0.769322  0.724924  0.194439  0.230678  0.275076
# 601    sub_6    6    TASK4T1     Ambos_Punos_Imaginado  0.702349  0.762083  0.687393  0.297651  0.237917  0.312607
# 602    sub_6    6    TASK4T2      Ambos_Pies_Imaginado  0.684794  0.688299  0.650279  0.315206  0.311701  0.349721
# 603    sub_6    7    TASK1T0                    Reposo  0.815757  0.799293  0.784985  0.184243  0.200707  0.215015
# 604    sub_6    7    TASK1T1       Mano_Izquierda_Real  0.821156  0.758702  0.747555  0.178844  0.241298  0.252445
# 605    sub_6    7    TASK1T2         Mano_Derecha_Real  0.814392  0.836170  0.758061  0.185608  0.163830  0.241939
# 606    sub_6    8    TASK2T0                    Reposo  0.788723  0.810104  0.802268  0.211277  0.189896  0.197732
# 607    sub_6    8    TASK2T1  Mano_Izquierda_Imaginado  0.755378  0.736431  0.755398  0.244622  0.263569  0.244602
# 608    sub_6    8    TASK2T2    Mano_Derecha_Imaginado  0.740660  0.711104  0.722713  0.259340  0.288896  0.277287
# 609    sub_6    9    TASK3T0                    Reposo  0.856527  0.792076  0.784503  0.143473  0.207924  0.215497
# 610    sub_6    9    TASK3T1          Ambos_Punos_Real  0.817179  0.805186  0.771469  0.182821  0.194814  0.228531
# 611    sub_6    9    TASK3T2           Ambos_Pies_Real  0.802046  0.738281  0.717792  0.197954  0.261719  0.282208
# 612    sub_7   10    TASK4T0                    Reposo  0.240082  0.224845  0.228090  0.759918  0.775155  0.771910
# 613    sub_7   10    TASK4T1     Ambos_Punos_Imaginado  0.314668  0.293860  0.294231  0.685332  0.706140  0.705769
# 614    sub_7   10    TASK4T2      Ambos_Pies_Imaginado  0.269973  0.301089  0.311124  0.730027  0.698911  0.688876
# 615    sub_7   11    TASK1T0                    Reposo  0.259569  0.241620  0.225689  0.740431  0.758380  0.774311
# 616    sub_7   11    TASK1T1       Mano_Izquierda_Real  0.320010  0.297553  0.287282  0.679990  0.702447  0.712718
# 617    sub_7   11    TASK1T2         Mano_Derecha_Real  0.302147  0.382160  0.286420  0.697853  0.617840  0.713580
# 618    sub_7   12    TASK2T0                    Reposo  0.236487  0.209844  0.203972  0.763513  0.790156  0.796028
# 619    sub_7   12    TASK2T1  Mano_Izquierda_Imaginado  0.198356  0.247879  0.221593  0.801644  0.752121  0.778407
# 620    sub_7   12    TASK2T2    Mano_Derecha_Imaginado  0.332776  0.310413  0.316703  0.667224  0.689587  0.683297
# 621    sub_7   13    TASK3T0                    Reposo  0.319066  0.266136  0.270266  0.680934  0.733864  0.729734
# 622    sub_7   13    TASK3T1          Ambos_Punos_Real  0.324747  0.355469  0.291639  0.675253  0.644531  0.708361
# 623    sub_7   13    TASK3T2           Ambos_Pies_Real  0.290807  0.301014  0.280004  0.709193  0.698986  0.719996
# 624    sub_7   14    TASK4T0                    Reposo  0.193109  0.211451  0.202904  0.806891  0.788549  0.797096
# 625    sub_7   14    TASK4T1     Ambos_Punos_Imaginado  0.262750  0.253031  0.239520  0.737250  0.746969  0.760480
# 626    sub_7   14    TASK4T2      Ambos_Pies_Imaginado  0.260167  0.244671  0.245342  0.739833  0.755329  0.754658
# 627    sub_7    3    TASK1T0                    Reposo  0.398815  0.346502  0.316092  0.601185  0.653498  0.683908
# 628    sub_7    3    TASK1T1       Mano_Izquierda_Real  0.364938  0.360991  0.318905  0.635062  0.639009  0.681095
# 629    sub_7    3    TASK1T2         Mano_Derecha_Real  0.393642  0.344619  0.315008  0.606358  0.655381  0.684992
# 630    sub_7    4    TASK2T0                    Reposo  0.252106  0.260426  0.217665  0.747894  0.739574  0.782335
# 631    sub_7    4    TASK2T1  Mano_Izquierda_Imaginado  0.460350  0.407227  0.401395  0.539650  0.592773  0.598605
# 632    sub_7    4    TASK2T2    Mano_Derecha_Imaginado  0.368002  0.367567  0.315614  0.631998  0.632433  0.684386
# 633    sub_7    5    TASK3T0                    Reposo  0.317874  0.303787  0.280462  0.682126  0.696213  0.719538
# 634    sub_7    5    TASK3T1          Ambos_Punos_Real  0.438838  0.430944  0.405225  0.561162  0.569056  0.594775
# 635    sub_7    5    TASK3T2           Ambos_Pies_Real  0.379477  0.417689  0.362490  0.620523  0.582311  0.637510
# 636    sub_7    6    TASK4T0                    Reposo  0.237154  0.233604  0.226814  0.762846  0.766396  0.773186
# 637    sub_7    6    TASK4T1     Ambos_Punos_Imaginado  0.328643  0.337381  0.280935  0.671357  0.662619  0.719065
# 638    sub_7    6    TASK4T2      Ambos_Pies_Imaginado  0.277033  0.275916  0.278426  0.722967  0.724084  0.721574
# 639    sub_7    7    TASK1T0                    Reposo  0.226381  0.216988  0.195650  0.773619  0.783012  0.804350
# 640    sub_7    7    TASK1T1       Mano_Izquierda_Real  0.294863  0.228330  0.225930  0.705137  0.771670  0.774070
# 641    sub_7    7    TASK1T2         Mano_Derecha_Real  0.391785  0.384871  0.352326  0.608215  0.615129  0.647674
# 642    sub_7    8    TASK2T0                    Reposo  0.227247  0.224782  0.221951  0.772753  0.775218  0.778049
# 643    sub_7    8    TASK2T1  Mano_Izquierda_Imaginado  0.267119  0.314606  0.288766  0.732881  0.685394  0.711234
# 644    sub_7    8    TASK2T2    Mano_Derecha_Imaginado  0.316807  0.336906  0.325320  0.683193  0.663094  0.674680
# 645    sub_7    9    TASK3T0                    Reposo  0.274017  0.241361  0.230190  0.725983  0.758639  0.769810
# 646    sub_7    9    TASK3T1          Ambos_Punos_Real  0.354286  0.383003  0.349864  0.645714  0.616997  0.650136
# 647    sub_7    9    TASK3T2           Ambos_Pies_Real  0.288861  0.348747  0.286797  0.711139  0.651253  0.713203
# 648    sub_8   10    TASK4T0                    Reposo  0.458216  0.433691  0.415857  0.541784  0.566309  0.584143
# 649    sub_8   10    TASK4T1     Ambos_Punos_Imaginado  0.337905  0.331149  0.297854  0.662095  0.668851  0.702146
# 650    sub_8   10    TASK4T2      Ambos_Pies_Imaginado  0.364075  0.363254  0.336568  0.635925  0.636746  0.663432
# 651    sub_8   11    TASK1T0                    Reposo  0.432411  0.446031  0.446172  0.567589  0.553969  0.553828
# 652    sub_8   11    TASK1T1       Mano_Izquierda_Real  0.375102  0.382094  0.334644  0.624898  0.617906  0.665356
# 653    sub_8   11    TASK1T2         Mano_Derecha_Real  0.380886  0.398632  0.395492  0.619114  0.601368  0.604508
# 654    sub_8   12    TASK2T0                    Reposo  0.437832  0.413750  0.396062  0.562168  0.586250  0.603938
# 655    sub_8   12    TASK2T1  Mano_Izquierda_Imaginado  0.394702  0.349635  0.338359  0.605298  0.650365  0.661641
# 656    sub_8   12    TASK2T2    Mano_Derecha_Imaginado  0.352758  0.305622  0.307870  0.647242  0.694378  0.692130
# 657    sub_8   13    TASK3T0                    Reposo  0.332657  0.304697  0.315508  0.667343  0.695303  0.684492
# 658    sub_8   13    TASK3T1          Ambos_Punos_Real  0.294586  0.297298  0.277801  0.705414  0.702702  0.722199
# 659    sub_8   13    TASK3T2           Ambos_Pies_Real  0.293892  0.314986  0.288452  0.706108  0.685014  0.711548
# 660    sub_8   14    TASK4T0                    Reposo  0.479392  0.487185  0.460222  0.520608  0.512815  0.539778
# 661    sub_8   14    TASK4T1     Ambos_Punos_Imaginado  0.457199  0.443263  0.477085  0.542801  0.556737  0.522915
# 662    sub_8   14    TASK4T2      Ambos_Pies_Imaginado  0.381606  0.404785  0.397948  0.618394  0.595215  0.602052
# 663    sub_8    3    TASK1T0                    Reposo  0.497898  0.491671  0.468634  0.502102  0.508329  0.531366
# 664    sub_8    3    TASK1T1       Mano_Izquierda_Real  0.545682  0.481627  0.407018  0.454318  0.518373  0.592982
# 665    sub_8    3    TASK1T2         Mano_Derecha_Real  0.514630  0.516645  0.424377  0.485370  0.483355  0.575623
# 666    sub_8    4    TASK2T0                    Reposo  0.463403  0.460601  0.430613  0.536597  0.539399  0.569387
# 667    sub_8    4    TASK2T1  Mano_Izquierda_Imaginado  0.433455  0.425383  0.343135  0.566545  0.574617  0.656865
# 668    sub_8    4    TASK2T2    Mano_Derecha_Imaginado  0.419913  0.420069  0.365014  0.580087  0.579931  0.634986
# 669    sub_8    5    TASK3T0                    Reposo  0.612647  0.618836  0.575056  0.387353  0.381164  0.424944
# 670    sub_8    5    TASK3T1          Ambos_Punos_Real  0.480320  0.507812  0.425302  0.519680  0.492188  0.574698
# 671    sub_8    5    TASK3T2           Ambos_Pies_Real  0.524470  0.510545  0.445691  0.475530  0.489455  0.554309
# 672    sub_8    6    TASK4T0                    Reposo  0.378585  0.330202  0.355592  0.621415  0.669798  0.644408
# 673    sub_8    6    TASK4T1     Ambos_Punos_Imaginado  0.314874  0.310632  0.275307  0.685126  0.689368  0.724693
# 674    sub_8    6    TASK4T2      Ambos_Pies_Imaginado  0.308809  0.290795  0.309721  0.691191  0.709205  0.690279
# 675    sub_8    7    TASK1T0                    Reposo  0.421121  0.381565  0.375674  0.578879  0.618435  0.624326
# 676    sub_8    7    TASK1T1       Mano_Izquierda_Real  0.341187  0.312500  0.291536  0.658813  0.687500  0.708464
# 677    sub_8    7    TASK1T2         Mano_Derecha_Real  0.343176  0.346801  0.315240  0.656824  0.653199  0.684760
# 678    sub_8    8    TASK2T0                    Reposo  0.459083  0.431080  0.404825  0.540917  0.568920  0.595175
# 679    sub_8    8    TASK2T1  Mano_Izquierda_Imaginado  0.326657  0.308867  0.307049  0.673343  0.691133  0.692951
# 680    sub_8    8    TASK2T2    Mano_Derecha_Imaginado  0.469915  0.406788  0.413445  0.530085  0.593212  0.586555
# 681    sub_8    9    TASK3T0                    Reposo  0.383748  0.312844  0.321951  0.616252  0.687156  0.678049
# 682    sub_8    9    TASK3T1          Ambos_Punos_Real  0.371910  0.363027  0.337495  0.628090  0.636973  0.662505
# 683    sub_8    9    TASK3T2           Ambos_Pies_Real  0.364369  0.351587  0.319762  0.635631  0.648413  0.680238
# 684    sub_9   10    TASK4T0                    Reposo  0.551479  0.550017  0.487500  0.448521  0.449983  0.512500
# 685    sub_9   10    TASK4T1     Ambos_Punos_Imaginado  0.664194  0.691656  0.564464  0.335806  0.308344  0.435536
# 686    sub_9   10    TASK4T2      Ambos_Pies_Imaginado  0.479981  0.533742  0.435133  0.520019  0.466258  0.564867
# 687    sub_9   11    TASK1T0                    Reposo  0.673516  0.650178  0.601181  0.326484  0.349822  0.398819
# 688    sub_9   11    TASK1T1       Mano_Izquierda_Real  0.553707  0.570069  0.518490  0.446293  0.429931  0.481510
# 689    sub_9   11    TASK1T2         Mano_Derecha_Real  0.594821  0.624992  0.561022  0.405179  0.375008  0.438978
# 690    sub_9   12    TASK2T0                    Reposo  0.576968  0.604126  0.478210  0.423032  0.395874  0.521790
# 691    sub_9   12    TASK2T1  Mano_Izquierda_Imaginado  0.631510  0.673553  0.587613  0.368490  0.326447  0.412387
# 692    sub_9   12    TASK2T2    Mano_Derecha_Imaginado  0.669319  0.702345  0.599140  0.330681  0.297655  0.400860
# 693    sub_9   13    TASK3T0                    Reposo  0.684947  0.824986  0.663550  0.315053  0.175014  0.336450
# 694    sub_9   13    TASK3T1          Ambos_Punos_Real  0.585830  0.693874  0.526250  0.414170  0.306126  0.473750
# 695    sub_9   13    TASK3T2           Ambos_Pies_Real  0.557299  0.708841  0.519453  0.442701  0.291159  0.480547
# 696    sub_9   14    TASK4T0                    Reposo  0.620905  0.813545  0.610119  0.379095  0.186455  0.389881
# 697    sub_9   14    TASK4T1     Ambos_Punos_Imaginado  0.665512  0.843384  0.636897  0.334488  0.156616  0.363103
# 698    sub_9   14    TASK4T2      Ambos_Pies_Imaginado  0.616969  0.821058  0.619414  0.383031  0.178942  0.380586
# 699    sub_9    3    TASK1T0                    Reposo  0.744658  0.833038  0.667024  0.255342  0.166962  0.332976
# 700    sub_9    3    TASK1T1       Mano_Izquierda_Real  0.735592  0.812976  0.632692  0.264408  0.187024  0.367308
# 701    sub_9    3    TASK1T2         Mano_Derecha_Real  0.710566  0.826078  0.644019  0.289434  0.173922  0.355981
# 702    sub_9    4    TASK2T0                    Reposo  0.643160  0.657652  0.532652  0.356840  0.342348  0.467348
# 703    sub_9    4    TASK2T1  Mano_Izquierda_Imaginado  0.709904  0.693515  0.596817  0.290096  0.306485  0.403183
# 704    sub_9    4    TASK2T2    Mano_Derecha_Imaginado  0.555416  0.584441  0.453508  0.444584  0.415559  0.546492
# 705    sub_9    5    TASK3T0                    Reposo  0.629192  0.783724  0.609579  0.370808  0.216276  0.390421
# 706    sub_9    5    TASK3T1          Ambos_Punos_Real  0.713623  0.803224  0.674173  0.286377  0.196776  0.325827
# 707    sub_9    5    TASK3T2           Ambos_Pies_Real  0.643379  0.760702  0.561663  0.356621  0.239298  0.438337
# 708    sub_9    6    TASK4T0                    Reposo  0.668705  0.828824  0.651006  0.331295  0.171176  0.348994
# 709    sub_9    6    TASK4T1     Ambos_Punos_Imaginado  0.650368  0.816325  0.616224  0.349632  0.183675  0.383776
# 710    sub_9    6    TASK4T2      Ambos_Pies_Imaginado  0.652488  0.834682  0.628341  0.347512  0.165318  0.371659
# 711    sub_9    7    TASK1T0                    Reposo  0.640121  0.660499  0.568523  0.359879  0.339501  0.431477
# 712    sub_9    7    TASK1T1       Mano_Izquierda_Real  0.575510  0.604718  0.493162  0.424490  0.395282  0.506838
# 713    sub_9    7    TASK1T2         Mano_Derecha_Real  0.644985  0.656899  0.568390  0.355015  0.343101  0.431610
# 714    sub_9    8    TASK2T0                    Reposo  0.620875  0.713065  0.553856  0.379125  0.286935  0.446144
# 715    sub_9    8    TASK2T1  Mano_Izquierda_Imaginado  0.673664  0.775376  0.639433  0.326336  0.224624  0.360567
# 716    sub_9    8    TASK2T2    Mano_Derecha_Imaginado  0.610058  0.783807  0.585419  0.389942  0.216193  0.414581
# 717    sub_9    9    TASK3T0                    Reposo  0.647451  0.713305  0.591962  0.352549  0.286695  0.408038
# 718    sub_9    9    TASK3T1          Ambos_Punos_Real  0.602984  0.687487  0.546053  0.397016  0.312513  0.453947
# 719    sub_9    9    TASK3T2           Ambos_Pies_Real  0.519997  0.556360  0.420430  0.480003  0.443640  0.579570

# %% [markdown]
#  ### *Referencias*
#
#  1. https://www.iar.unlp.edu.ar/boletin/interfaces-cerebro-maquina/
#
#  2. https://www.nature.com/articles/s41598-018-20125-6
#
#  3. https://www.sciencedirect.com/science/article/pii/S2405896321016876
#
#  4. https://pmc.ncbi.nlm.nih.gov/articles/PMC5810272/
#
#  5. https://www.ninds.nih.gov/health-information/clinical-trials/stroke-rehabilitation-using-brain-computer-interface-bci-technology
#
#  6. https://www.nature.com/articles/s44385-025-00029-7
#
#  7. https://www.ionos.com/es-us/digitalguide/paginas-web/desarrollo-web/brain-computer-interface/
#
#  8. https://www.bitbrain.com/es/aplicaciones/interfaces-cerebro-computador
#
#  9. https://ineurociencias.org/brain-computer-interfaces-for-basic-neuroscience/
#
#  10. https://pmc.ncbi.nlm.nih.gov/articles/PMC6471241/
#
#  11. https://pmc.ncbi.nlm.nih.gov/articles/PMC6387242/
#
#  12. https://pysdr.org/es/content-es/filters.html   filtros FIR/IIR MANUAL
#
#  13. https://mne.tools/1.3/auto_tutorials/preprocessing/30_filtering_resampling.html INTEGRADO EN MNE
#
#  14. https://pmc.ncbi.nlm.nih.gov/articles/PMC12970966/  tiene un link de git hub donde hacen esto mismo pero mas avanzado nos puede servir
#
#  15. https://www3.fi.mdp.edu.ar/tds/material/10-Filtros%20FIR.pdf
#
#  16. https://www.elsevier.es/es-revista-revista-colombiana-psiquiatria-379-articulo-cambios-el-eeg-reposo-exparticipantes-S0034745017300288#:~:text=Las%20medidas%20de%20potencia%20se%20normalizaron%20dividiendo,registro%20para%20el%20c%C3%A1lculo%20de%20la%20potencia.
